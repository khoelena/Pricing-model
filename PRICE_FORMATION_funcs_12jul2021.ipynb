# %% [markdown]
# ### Подключение библиотек

# %%
#!pip install C:\Users\elena.khotlyannik\Documents\AA\feature-selector
#!pip install hyperopt
#!pip install optuna
#!pip install nlopt

# %%
import pyodbc 

import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer as dv

from feature_selector import FeatureSelector

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import StackingRegressor

import hyperopt
from hyperopt import hp, fmin, tpe
from hyperopt.pyll.base import scope
from hyperopt import STATUS_OK, Trials, SparkTrials

import optuna
import pickle
import nlopt

from scipy.stats import pearsonr

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Определение переменных по умолчанию

# %%
# parameters for DATA LOADING:
# 1
# load_table_from - to define what type of loading from data source need to be chosen
# value options: 'db' or 'file'
load_type = 'db'  # values: 'db' or 'file'

# 1.1 group of parameters, which are required if load_table_from = 'db'
pc_driver = 'SQL Server'
pc_server = '.'
pc_database = 'PRICE_FORMATION'
# pc_table   /table with price context data/
pc_table = 'sales_price_context'
# plan_table   /table with plan for product+store data/
plan_table = 'target_product_store_plan'

# 1.2 parameter, which is required if load_table_from = 'file'
# pc_file_data_path /file with price context data /
pc_file_path = 'C:\\Users\\elena.khotlyannik\\Documents\\AA\\milks.csv'
plan_file_path = 'target_product_store_plan.csv'

# 2
# parameters for data preparation

test_proportion = 0.2  #for train/test
target = ['s_count']
#   Определяю признаки, которые не являются предикторами для моделей
special_cols = ['s_date', 'product_id'] + target
#   Определяю категориальные признаки, которые предполагается разложить на  0 1
categorical_cols = ['product_type', 'product_subtype', 'product_category']

test_hyperopt_proportion = 0.2

# 3
# parameters for models
global_var_evals = 32
global_verbose = 0
# 3.1 for GradientBoostingRegressor model (gbr_model)
gbr_param_definition = 'by_optuna' # or 'from_global_vars' or 'load_from_file' or 'by_hyperopt'
# if gbr_param_definition='from_file':
gbr_param_file = 'C:\\Users\\elena.khotlyannik\\Documents\\AA\\gbr_params.csv'
# if gbr_param_definition='from_global_vars':
gbr_max_features = 1
gbr_n_estimators = 1
gbr_learning_rate = 1
gbr_max_depth = 1

# 3.2 for RandomForestRegressor model (rf_model)
rf_param_definition = 'by_optuna'  # 'by_hyperopt' or 'from_global_vars' or 'load_from_file' or 'by_optuna'
# if rf_param_definition='from_file':
rf_param_file = 'C:\\Users\\elena.khotlyannik\\Documents\\AA\\rf_params.csv'
# if rf_param_definition='from_global_vars':
rf_max_features = 2
rf_n_estimators = 2
rf_max_samples = 2
rf_max_depth = 2

# 4.
# parameters for FeatureSelector
fs_cumulative_importance = 0.95
fs_from_file = 'N'
fs_file_path = 'C:\\Users\\elena.khotlyannik\\Documents\\AA\\features_to_remove.csv'
#исключение из листа исключений (список полей, которые не надо исключать из предикторов)
feature_exceptions = ['store_id', 'price', 'year', 'month', 'day']

# %% [markdown]
# ### Функции загрузки данных

# %%
# load_df - function do for data loading
# parameters:
#      load_table_from
#       file_path
#       output_table
#       driver
#       server
#       database


def load_data(load_type=load_type,
              file_path=plan_file_path,
              driver=pc_driver,
              server=pc_server,
              database=pc_database,
              input_table=pc_table):
    result_table = pd.DataFrame
    if load_type == 'db':
        print("Start loading data from " + database + '.' + input_table)
        conn = pyodbc.connect("driver={" + driver + "}; server=" + server + "; database=" + database)
        cur = conn.cursor()
        cur.execute("SELECT * FROM " + input_table)
        cols = [column[0] for column in cur.description]
        input_table1 = input_table
        input_table = cur.fetchall()
        type(input_table)
        cur.close()
        conn.close()
        result_table = pd.DataFrame.from_records(input_table)
        result_table.columns = cols
        print("Finish loading data from " + database + '.' + input_table1)

    elif load_type == 'file':
        print("Start loading data from file " + file_path)
        result_table = pd.read_csv(file_path, sep=',', engine="python", encoding='utf8')
        print("Finish loading data from file " + file_path)

    return result_table


# load_pc - function for price_context loading


def load_pc(load_type=load_type,
            file_path=pc_file_path,
            driver=pc_driver,
            server=pc_server,
            database=pc_database,
            input_table=pc_table):
    result_table = load_data(load_type=load_type,
                             file_path=file_path,
                             driver=driver,
                             server=server,
                             database=database,
                             input_table=input_table)
    return result_table


# load_plan - function for target_plan loading


def load_plan(load_type=load_type,
            file_path=plan_file_path,
            driver=pc_driver,
            server=pc_server,
            database=pc_database,
            input_table=plan_table):
    result_table = load_data(load_type=load_type,
                             file_path=file_path,
                             driver=driver,
                             server=server,
                             database=database,
                             input_table=input_table)
    return result_table


# Загрузка гиперпараметров для модели из файла


def load_params(file_path):
    params = load_data(load_type='file', file_path=file_path)
    best = {}
    for i in range(0, len(params.columns)):
        best.update({params.iloc[0][i]: float(params.iloc[1][i])})

    return best


# Загрузка предикторов, которые надо удалить из датасета для обучения модели. Из файла


def load_features(file_path):
    list_to_remove = load_data(load_type='file', file_path=file_path)
    list_to_remove = list_to_remove.iloc[0].tolist()

    return list_to_remove

# %% [markdown]
# ### Функции предобработки данных, разделения test/train, X/y

# %%
def data_prepare(data_table,
                 special_cols=special_cols,
                 categorical_cols=categorical_cols):

    #   Добавляю ГОД МЕСЯЦ ДЕНЬ из s_date
    price_context.loc[:,'s_date']   = data_table.loc[:, 's_date'].apply(pd.to_datetime)
    price_context.loc[:,'year'] = data_table.loc[:, 's_date'].apply(lambda x : x.year)
    price_context.loc[:,'month'] = data_table.loc[:, 's_date'].apply(lambda x : x.month)
    price_context.loc[:,'day'] = data_table.loc[:, 's_date'].apply(lambda x : x.day)
    
    #отделяю столбцы group_l* , так как они не идуд в обучение. group_l нужно только для пересчета контекста при оптимизации
    groupl_cols = []
    groupl_cols = [col for col in data_table.columns if 'group_l' in col] 
    groupls = data_table[groupl_cols]
    
   
    #   Отделяю special_cols, чтобы потом все собрать (concat)
    spec = data_table[special_cols]       
    
    #   Определяю вещественные признаки, по каторым предполагается заполнить пустые значения нулями
    numeric_cols = list(set(data_table.columns.values.tolist()) - set(categorical_cols) - set(special_cols) - set(groupl_cols))

    #   Для вещественных признаков заменяю null на 0
    zeros = data_table[numeric_cols].fillna(0)
    
    #   Для категориальных признаков  "nan" заменяем на "NA"
    cat=data_table[categorical_cols].astype(str)
    for column in cat.columns:
        cat[column].fillna(value='Na', inplace=True)
        
    # Раскладываю категориальные принаки на  0 1
    from sklearn.feature_extraction import DictVectorizer as DV
    encoder = DV(sparse = False)
    cat2 = encoder.fit_transform(cat.T.to_dict().values())
    cat2=pd.DataFrame(cat2)
    cat2.columns = encoder.feature_names_
    
    # Идею сделать Mean Embanding для категориальных признаков не реализовала
    


    #   Собираю обратно
    data_table_prepared=pd.concat([spec,groupls,zeros,cat2],axis=1) 
    
    return data_table_prepared, groupl_cols

# %%
def test_train_split(data_table,
                     test_proportion=test_proportion):
    
    #   получаю список уникальных  дат, отсортированных по возрастанию
    s_date_list = pd.DataFrame(data_table['s_date'].unique()).sort_values(by=0, ascending=True)

    #   определяю количество дат, которые пойдут в test
    test_count = round(len(s_date_list)*test_proportion)

    #   список дат s_date_list отсортирован, поэтому последние  test_count дат идут в s_date_list_test
    s_date_list_test = s_date_list.iloc[-test_count:, :]

    #   min(s_date_list_test[0])   = разделяющая дата. Записи, у которых s_date меньше идут в train, остальное в test
    data_table_train = data_table[data_table['s_date'] < min(s_date_list_test[0])]
    data_table_test = data_table[data_table['s_date'] >= min(s_date_list_test[0])]

    return data_table_train, data_table_test

# %%
def x_y_split(data_table,
              target):
    
    column_to_delete = special_cols + groupl_cols

    data_table_x = data_table.drop(column_to_delete, axis=1)
    data_table_y = data_table[target]

    return data_table_x, data_table_y

# %% [markdown]
# ### Функция ошибки - ОТНОШЕНИЕ СРЕДНИХ WMAPE

# %%
def wmape(y_true, y_pred): 
    wmape = 100 * np.sum(np.abs(np.array(y_true) - np.array(y_pred))) /np.sum(np.array(y_true))
   
    return  wmape

# %% [markdown]
# ### Функция отбора предикторов

# %%
# Отбор предикторов по продукту+магазину
# Возвращает лист c предикторами, которые надо удалить, list_to_remove

def feature_selector(x_data=None,
                     y_data=None,
                     cumulative_importance=None,
                     exceptions=feature_exceptions,
                     from_file=None,
                     file_path=None):
    
    if from_file is None or from_file != 'Y':
        from_file = fs_from_file
    
    if from_file == 'Y':
        if file_path is None:
            file_path = fs_file_path
        list_to_remove = load_features(file_path)

    else:
        if cumulative_importance is None:
            cumulative_importance = fs_cumulative_importance
        fs = FeatureSelector(data=x_data, labels=y_data)
        fs.identify_zero_importance(task='regression',
                                    n_iterations=10,
                                    early_stopping=False)
        fs.identify_low_importance(cumulative_importance)
        list_to_remove = fs.record_low_importance.feature.tolist()
        #print('list_to_remove:', list_to_remove)
        #print('exceptions:', exceptions)
        for feature in exceptions:
                if feature in list_to_remove:
                   # print(feature)
                    list_to_remove.remove(feature)
    # return list of features to remove
    return list_to_remove

#  Возвращает датасет с удаленными 
def remove_features(data_table,list_to_remove):
    data_table = data_table.drop(list_to_remove, axis=1, errors='ignore')

    return data_table

# %% [markdown]
# #### Функции подбора гиперпараметров gbr_hyperopt, rf_hyperopt,  gbr_optuna , rf_optuna
# ###### имеет смысл сделать функции для hyperopt вообще, а потом функции  gbr_hyperopt, rf_hyperopt на ее базе. Так же и optuna.
# ##### передавать параметры для сетки через атрибуты вызова функции

# %%
#   ПОДБОР ПАРАМЕТРОВ для градиентного бустинга HYPEROPT
def gbr_hyperopt(x_train_train, y_train_train, x_train_test, y_train_test, evals):
    
    max_evals = evals
    def objective(space):
        g_model = GradientBoostingRegressor(
            loss='ls',
            random_state=0,
            max_features=space["max_features"],
            n_estimators=space["n_estimators"],
            learning_rate=space["learning_rate"],
            max_depth=space["max_depth"]
        )

        g_model.fit(x_train_train, y_train_train)
        y_predict = np.float64(g_model.predict(x_train_test))
        res = wmape(y_train_test, y_predict)

        return {'loss': res, 'status': STATUS_OK,
                'n_estimators': g_model.n_estimators,
                'learning_rate': g_model.learning_rate,
                'max_depth': g_model.max_depth}

    #   Распределения переменных.
    space = {'n_estimators': scope.int(hp.quniform('n_estimators',  10, 500, 20)),
             'learning_rate': hp.loguniform('learning_rate', -6.9, 2.3),
             'max_depth': scope.int(hp.quniform('max_depth', 2, 10, 2)) ,
             'max_features': scope.int(hp.quniform('max_features', 2, max(4,x_train_train.shape[1]-3),2))
             }
    
  #  spark_trials = pyspark.SparkTrials(parallelism=8)
    #   Поиск лучших параметров GradientBoostingRegressor.
    trials = Trials()
    best = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=max_evals
    )

    return best

# %%
def rf_hyperopt(x_train_train, y_train_train, x_train_test, y_train_test, evals):

    max_evals = evals

    # Целевая функция.
    def objective(space):
        rf_model = RandomForestRegressor(
            random_state=0,
            n_estimators=space["n_estimators"],
            max_depth=space["max_depth"],
            max_features=space["max_features"]
        )

        rf_model.fit(x_train_train, y_train_train)
        y_predict = np.float64(rf_model.predict(x_train_test))
        res = wmape(y_train_test, y_predict)

        return {'loss': res, 'status': STATUS_OK,
                'n_estimators': rf_model.n_estimators,
                'max_depth': rf_model.max_depth,
                'max_features': rf_model.max_features
                }

    # Распределения переменных.
    space = {
        'n_estimators':  scope.int(hp.quniform('n_estimators', 10, 500, 10)),
        'max_depth':     scope.int(hp.quniform('max_depth', 2, 20, 2)),
        'max_features':  scope.int(hp.quniform('max_features', 2, max(4,x_train_train.shape[1]-3),2))
    }

    # Поиск лучших параметров Random Forest.
    trials = Trials()
    best = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=max_evals,
        trials=trials
    )

    return best

# %%
#   ПОДБОР ПАРАМЕТРОВ для градиентного бустинга OPTUNA
def gbr_optuna(x_train_train, y_train_train, x_train_test, y_train_test, evals):

    class Objective:
        def __init__(self):
            global x_train_train, y_train_train, x_train_test, y_train_test

        def __call__(self, trial):
            
            params = {
                'n_estimators': trial.suggest_int('n_estimators', 10, 500),
                'learning_rate': trial.suggest_uniform('learning_rate', 0.00, 2),
                'max_depth': trial.suggest_int('max_depth', 2, 20) ,
                'max_features': trial.suggest_int('max_features', 3, max(3,x_train_train.shape[1]-3))
                }    

            gbr_model = GradientBoostingRegressor(**params)
            gbr_model.fit(x_train_train, y_train_train)
            y_predict = np.float64(gbr_model.predict(x_train_test))
            res = wmape(y_train_test, y_predict)

            return res 

    # Use Optuna to find the hyperparameters with the highest score    
  #  print('Hyperparameter optimization starting.')
    objective = Objective() #.values.ravel())
    study_gbr = optuna.create_study(direction='minimize', study_name='optuna_GradientBoostingRegressor', load_if_exists=True)
    study_gbr.optimize(objective, n_trials=evals ,n_jobs=-1)
    hist_df_rf = study_gbr.trials_dataframe()

  #  print("Optimized params: {}".format(study_gbr.best_params))

    return study_gbr

# %%
#   ПОДБОР ПАРАМЕТРОВ для Random Forest OPTUNA
def rf_optuna(x_train_train, y_train_train, x_train_test, y_train_test, evals):

    class Objective:
        def __init__(self):
            global x_train_train, y_train_train, x_train_test, y_train_test

        def __call__(self, trial):

            params = {
                'n_estimators':  trial.suggest_int('n_estimators', 100, 500),
                'max_depth':     trial.suggest_int('max_depth', 2, 10),
                'max_features':  trial.suggest_int('max_features', 3, max(3,x_train_train.shape[1]-3))
                }    

            rf_model = RandomForestRegressor(**params)
            rf_model.fit(x_train_train, y_train_train)
            y_predict = np.float64(rf_model.predict(x_train_test))
            res = wmape(y_train_test, y_predict)

            return res 

    # Use Optuna to find the hyperparameters with the highest score    
  #  print('Hyperparameter optimization starting.')
    objective = Objective() #.values.ravel())
    study_rf = optuna.create_study(direction='minimize', study_name='optuna_RandomForest', load_if_exists=True)
    study_rf.optimize(objective, n_trials=evals ,n_jobs=-1)
    hist_df_rf = study_rf.trials_dataframe()

   # print("Optimized params: {}".format(study_rf.best_params))

    return study_rf

# %% [markdown]
# ### Функция создания модели с заданными параметрами

# %%
#   Создание модели
def model_formation(X_train_train=None, X_train_test=None, y_train_train=None, y_train_test=None,
                    model_type='gbr',  # 'gbr' / 'rf'  (GradientBoostingRegressor / RandomForestRegressor)
                    param_definition=None,
                    # 'by_hyperopt' / 'by_optuna' / 'from_global_vars' / 'from_file' / none (если none, то параметры для модели надо задать при вызове функции)
                    param_file=None,
                    max_features=None,  # used for gbr and rf
                    n_estimators=None,  # used for gbr and rf
                    learning_rate=None,  # used for gbr
                    max_depth=None,  # used for gbr and rf
                    evals = global_var_evals,
                    verbose = global_verbose
                    ):
    
    best = {}
    if param_definition is None and max_features is None:
        if model_type == 'gbr':
            param_definition = gbr_param_definition
        if model_type == 'rf':
            param_definition = rf_param_definition

    elif param_definition is None and max_features is not None:
        #  Определение гиперпараметров
        best["max_features"] = max_features
        best["n_estimators"] = n_estimators
        best["learning_rate"] = learning_rate
        best["max_depth"] = max_depth


    if param_definition == 'from_file':
        if param_file is None:
            if model_type == 'gbr':
                param_file = gbr_param_file
            if model_type == 'rf':
                param_file = rf_param_file
        best = load_params(param_file)


    elif param_definition == 'by_hyperopt':
        if model_type == 'gbr':
            best = gbr_hyperopt(X_train_train, X_train_test, y_train_train, y_train_test, evals)
        elif model_type == 'rf':
            best = rf_hyperopt(X_train_train, X_train_test, y_train_train, y_train_test, evals)
            
    elif param_definition == 'by_optuna':
        if model_type == 'gbr':
            best = gbr_optuna(X_train_train, X_train_test, y_train_train, y_train_test, evals).best_params
        elif model_type == 'rf':
            best = rf_optuna(X_train_train, X_train_test, y_train_train, y_train_test, evals).best_params

    elif param_definition == 'from_global_vars':
        if model_type == 'gbr':
            best["max_features"] = gbr_max_features
            best["n_estimators"] = gbr_n_estimators
            best["learning_rate"] = gbr_learning_rate
            best["max_depth"] = gbr_max_depth

        elif model_type == 'rf':
            best["max_features"] = rf_max_features
            best["n_estimators"] = rf_n_estimators
            best["max_depth"] = rf_max_depth

    if model_type == 'gbr':
        default_model = GradientBoostingRegressor(
            random_state=0,
            max_features=int(best["max_features"]),
            n_estimators=int(best["n_estimators"]),
            learning_rate=np.float16(best["learning_rate"]),
            max_depth=int(best["max_depth"]),
            verbose=verbose
        )

    elif model_type == 'rf':
        default_model = RandomForestRegressor(
            random_state=0,
            max_features=int(best["max_features"]),
            n_estimators=int(best["n_estimators"]),
            max_depth=int(best["max_depth"]),
            verbose=verbose
        )

   # print(best)

    return default_model

# %% [markdown]
# ### Функции задания ансамбля

# %%
def sr_stacking(list_of_models,models2level):

    level1_estimators = []
  #  print(list_of_models)
  #  print(level1_estimators)
    i = 1
    for model in list_of_models:
        model_name_str = 'model' + str(i)
        i += 1
        level1_estimators.append((model_name_str, model))

 #   print(level1_estimators)
    ensemble_stack = StackingRegressor(
        estimators=level1_estimators,
        final_estimator=models2level,
        passthrough = True,
        n_jobs = -1
    )

    return ensemble_stack

# %% [markdown]
# ### Функция расчета y_predict, wmape, корреляции пирсона,  также сохранения в словарь

# %%
def y_wmape_calc_save(product, store, model, model_tag, X_test, y_test, X_train):
    
    y_predict_test = model.predict(X_test)
    res_test = wmape(y_test, y_predict_test)
    
    dict_for_model[str(product)+str(store)][model_tag] = model
    dict_for_model[str(product)+str(store)][model_tag+'_y_predict'] = y_predict_test
    dict_for_model[str(product)+str(store)]['wmape_'+model_tag+'_test'] = res_test
    
    
    y_predict_test = pd.DataFrame(y_predict_test)
    y_predict_test.columns = ['y_predict']
    product_df_sort = pd.concat([X_test['price'].reset_index(),y_test.reset_index(),y_predict_test.reset_index()],axis=1).sort_values(['price'])
    #print(product_df_sort)
    r, p_value = pearsonr(product_df_sort['s_count'], product_df_sort['y_predict'])
          
          
    dict_for_model[str(product)+str(store)]['r_'+model_tag+'_test'] = r          
    dict_for_model[str(product)+str(store)]['p_value_'+model_tag+'_test'] = p_value
    
    dict_for_model[str(product)+str(store)][model_tag+'_columns'] = X_train.columns     
        
    return

# %% [markdown]
# ### Функция проверки качества/удаления плохих моделей из dictionary

# %%
# dict_to_check  = name of dictionary with models
# model_tag = 'stacking'
# mark_type = 'wmape' / 'pearsonr' / 'all' = both
# mark_value:   
        #for mark_type = 'wmape' , mark_value = wmape     
        #for mark_type = 'pearsonr' , mark_value = [r , p-value]
        #                                         r - Pearson’s correlation coefficient
        #                                         p - value Two-tailed p-value
        # for mark_type = 'all' , mark_value = [r , p-value, wmape]
        #                                         r - Pearson’s correlation coefficient
        #                                         p - value Two-tailed p-value
        #                                         wmape = wmape
# drop_from_dict = True - удаление из словаря моделей, по которым не прошла проверка качества

def model_control(dict_to_check, model_tag, mark_type, mark_value, drop_from_dict=False):
    
    
    if mark_type == 'wmape':
        table_to_show = pd.DataFrame(dict_to_check).T['wmape_'+model_tag+'_test']
        table_to_show.column = ['wmape_'+model_tag+'_test']
        table_to_show.index.name = 'product_store'
        table_to_show = pd.DataFrame(table_to_show)
        table_to_show['good_estimate'] = (table_to_show['wmape_'+model_tag+'_test'] <= mark_value)    

        list_to_pop = table_to_show[(table_to_show['wmape_'+model_tag+'_test'] <= mark_value) == False ] .index.tolist()
            
            
    elif mark_type == 'pearsonr':
    
        table_to_show = pd.DataFrame(dict_to_check).T[['r_'+model_tag+'_test','p_value_'+model_tag+'_test' ]]
        table_to_show.columns = ['r_'+model_tag+'_test','p_value_'+model_tag+'_test']
        table_to_show.index.name = 'product_store'
        table_to_show = pd.DataFrame(table_to_show)
        table_to_show['good_estimate'] = ((abs(table_to_show['r_'+model_tag+'_test']) >= mark_value[0]) 
                                          & (table_to_show['p_value_'+model_tag+'_test' ] <= mark_value[1])) 

        list_to_pop = table_to_show[((abs(table_to_show['r_'+model_tag+'_test']) >= mark_value[0]) 
                                         & (table_to_show['p_value_'+model_tag+'_test'] <= mark_value[1])) == False].index.tolist()
                                
                                
                                
    elif mark_type == 'all':
    
        table_to_show = pd.DataFrame(dict_to_check).T[['r_'+model_tag+'_test','p_value_'+model_tag+'_test','wmape_'+model_tag+'_test']]
        table_to_show.columns = ['r_'+model_tag+'_test','p_value_'+model_tag+'_test' ,'wmape_'+model_tag+'_test']
        table_to_show.index.name = 'product_store'
        table_to_show = pd.DataFrame(table_to_show)
        table_to_show['good_estimate'] = ((abs(table_to_show['r_'+model_tag+'_test']) >= mark_value[0]) 
                                          & (table_to_show['p_value_'+model_tag+'_test' ] <= mark_value[1]) 
                                          & (table_to_show['wmape_'+model_tag+'_test'] <= mark_value[2])   ) 

    

        list_to_pop = table_to_show[((abs(table_to_show['r_'+model_tag+'_test']) >= mark_value[0]) 
                                         & (table_to_show['p_value_'+model_tag+'_test'] <= mark_value[1]) 
                                         & (table_to_show['wmape_'+model_tag+'_test'] <= mark_value[2])) == False].index.tolist()

                    
    else:
        print('Wrong mark_type. Function model_control() expects mark_type = "wmape" or "pearsonr" or "all".')
              
    
    if drop_from_dict == True:
            [dict_to_check.pop(key) for key in list_to_pop]  
       
    return dict_to_check, table_to_show

# %%
def correlations_draw(dict_for_model, product_store_list, model_tag):
    if len(product_store_list) == 0:
        product_store_list = dict_for_model.keys()
    
    i = 0
    print(len(product_store_list))
    for ps in product_store_list:
        if model_tag in dict_for_model[ps].keys():
            r = dict_for_model[ps]['r_'+model_tag+'_test']
            p_value = dict_for_model[ps]['p_value_'+model_tag+'_test']
            wmape = dict_for_model[ps]['wmape_'+model_tag+'_test']
            y_predict = pd.DataFrame(dict_for_model[ps][model_tag+'_y_predict'])
            y_predict.columns = ['y_predict']
            dt = pd.concat( [pd.concat([dict_for_model[ps]['price_test'],dict_for_model[ps]['s_count_test']],axis=1).reset_index(),
                            y_predict], axis = 1).sort_values(['price']).reset_index()
            #print(dt)
            plt.figure(figsize=(12,4))
            plt.plot(dt['price'],dt['s_count'],label='fact')
            plt.plot(dt['price'],dt['y_predict'], label='predict')
            plt.title(str(ps)+ '. wmape = ' + str(round(wmape,4)) + '. r = ' + str(round(r,4)) + '. p_value = ' + str(p_value))
            plt.legend(loc='upper right', frameon=False)
            plt.xlabel('Price')
            plt.ylabel('Sales')
            #lt.xticks(np.arange(0, len(dt['price'])+1, 2))
            plt.show()
    return

# %% [markdown]
# ## Собственно начало основного блока (вызов функций загрузки данных, предобработки)

# %%
price_context = load_pc() #load_type='db'
target_plan = load_plan()
# Out:
# Start loading data from PRICE_FORMATION.sales_price_context
# Finish loading data from PRICE_FORMATION.sales_price_context
# Start loading data from PRICE_FORMATION.target_product_store_plan
# Finish loading data from PRICE_FORMATION.target_product_store_plan

# %%
pc_prepared, groupl_cols = data_prepare(price_context)
#pc_prepared - датасет для моделирования, 
#groupl_cols - перечень атрибутов (наименование уровней группировок) не участвующих в моделировании, но необходимых для оптимизации

pc_prepared_train, pc_prepared_test = test_train_split(data_table=pc_prepared, test_proportion=0.2)

# %% [markdown]
# #### ДАЛЕЕ ПОДБОР ГИПЕРПАРАМЕТРОВ И ОБУЧЕНИЕ МОДЕЛИ ДЛЯ КАЖДОГО PRODUCT_ID + STORE_ID

# %% [markdown]
# #### Цикл по продуктам

# %%
dict_for_model = {}
#from sklearn import model_selection

i=1
for product in pc_prepared['product_id'].unique():
    for store in pc_prepared['store_id'].unique():
        i=i+1
        product_pc_prepared_train = pc_prepared_train[(pc_prepared_train['product_id']==product) & (pc_prepared_train['store_id']==store)]
        product_pc_prepared_test =  pc_prepared_test[(pc_prepared_test['product_id']==product) & (pc_prepared_test['store_id']==store)]
              
        product_X_train, product_y_train = x_y_split(data_table=product_pc_prepared_train, target='s_count')
        product_X_test, product_y_test = x_y_split(data_table=product_pc_prepared_test, target='s_count')
                     
        if len(product_pc_prepared_train)>4 and len(product_pc_prepared_test)>0 and np.sum(np.array(product_pc_prepared_test['s_count']))!=0:
        
            #отбор предикторов 
            features_to_remove = feature_selector(product_X_train, product_y_train, 0.9)
            product_X_train_fs = remove_features(product_X_train, features_to_remove)
            product_X_test_fs = remove_features(product_X_test, features_to_remove)
            product_pc_prepared_train_fs = remove_features(product_pc_prepared_train, features_to_remove)
            product_pc_prepared_test_fs = remove_features(product_pc_prepared_test, features_to_remove)
            
            print(i)
            pc_prepared_train_train, pc_prepared_train_test = test_train_split(data_table=product_pc_prepared_train_fs, test_proportion=0.2)          
            X_train_train, X_train_test = x_y_split(data_table=pc_prepared_train_train, target='s_count')
            y_train_train, y_train_test = x_y_split(data_table=pc_prepared_train_test, target='s_count')

            if len(X_train_train)>4 and len(X_train_test)>0 and np.sum(np.array(product_y_test))!=0 and np.sum(np.array(y_train_test))!=0  :

                dict_for_model[str(product)+str(store)] = {}                
                dict_for_model[str(product)+str(store)]['s_count_test'] = product_y_test
                dict_for_model[str(product)+str(store)]['price_test'] = product_X_test['price']
                
                
                #GradientBoostingRegressor
                ##optuna
                gbr_model_optuna = model_formation(X_train_train, X_train_test, y_train_train, y_train_test,
                                                    model_type='gbr', param_definition='by_optuna')
                
                #Random Forest
                ##optuna
                rf_model_optuna = model_formation(X_train_train, X_train_test, y_train_train, y_train_test,
                                                    model_type='rf', param_definition='by_optuna')  
                
                #Ансамбль моделей  
                stacking_model = sr_stacking((rf_model_optuna,gbr_model_optuna), 
                                              RandomForestRegressor(max_depth=rf_model_optuna.max_depth, 
                                                                    n_estimators=rf_model_optuna.n_estimators,
                                                                    random_state=0))
                stacking_model.fit(product_X_train_fs, product_y_train)
                
                y_wmape_calc_save(product=product, store=store, model=stacking_model, model_tag='stacking', 
                                  X_test=product_X_test_fs, y_test=product_y_test, X_train=product_X_train_fs)
                
               # stacking_modelB = MYMODEL(max_depth=rf_model_optuna.max_depth, 
               #                                                     n_estimators=rf_model_optuna.n_estimators,
               #                                                     random_state=0)
               # stacking_modelB.fit(product_X_train_fs, product_y_train)
               # 
               # y_wmape_calc_save(product=product, store=store, model=stacking_modelB, model_tag='stackingB', 
               #                   X_test=product_X_test_fs, y_test=product_y_test)
# Out:
# Training Gradient Boosting Model
# [I 2021-07-16 12:03:47,164] A new study created in memory with name: optuna_GradientBoostingRegressor
# 79 features with zero importance after one-hot encoding.
#
# 24 features required for cumulative importance of 0.90 after one hot encoding.
# 97 features do not contribute to cumulative importance of 0.90.
#
# 2
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:03:47,535] Trial 5 finished with value: 83.09504369680394 and parameters: {'n_estimators': 35, 'learning_rate': 1.0799818569903883, 'max_depth': 11, 'max_features': 7}. Best is trial 5 with value: 83.09504369680394.
# [I 2021-07-16 12:03:47,899] Trial 4 finished with value: 111.77623319841861 and parameters: {'n_estimators': 66, 'learning_rate': 1.6043884814292586, 'max_depth': 11, 'max_features': 16}. Best is trial 5 with value: 83.09504369680394.
# [I 2021-07-16 12:03:48,022] Trial 8 finished with value: 120.61669354570432 and parameters: {'n_estimators': 94, 'learning_rate': 1.4873279774085968, 'max_depth': 5, 'max_features': 15}. Best is trial 5 with value: 83.09504369680394.
# [I 2021-07-16 12:03:48,043] Trial 9 finished with value: 90.79865806151255 and parameters: {'n_estimators': 23, 'learning_rate': 0.9845678246859129, 'max_depth': 10, 'max_features': 6}. Best is trial 5 with value: 83.09504369680394.
# [I 2021-07-16 12:03:48,202] Trial 7 finished with value: 309.7557114253173 and parameters: {'n_estimators': 95, 'learning_rate': 1.9561745297327842, 'max_depth': 17, 'max_features': 16}. Best is trial 5 with value: 83.09504369680394.
# [I 2021-07-16 12:03:48,594] Trial 6 finished with value: 69.22308821928607 and parameters: {'n_estimators': 499, 'learning_rate': 0.8143989340424409, 'max_depth': 19, 'max_features': 7}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:48,819] Trial 0 finished with value: 115.16660796850772 and parameters: {'n_estimators': 412, 'learning_rate': 1.3964076587940395, 'max_depth': 18, 'max_features': 3}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:48,959] Trial 3 finished with value: 92.19514439670633 and parameters: {'n_estimators': 489, 'learning_rate': 1.0471389100937807, 'max_depth': 6, 'max_features': 4}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:49,127] Trial 15 finished with value: 70.07555086110784 and parameters: {'n_estimators': 15, 'learning_rate': 0.8964278052810901, 'max_depth': 20, 'max_features': 17}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:49,162] Trial 2 finished with value: 75.00952392892135 and parameters: {'n_estimators': 285, 'learning_rate': 1.0427288952856695, 'max_depth': 15, 'max_features': 22}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:49,601] Trial 14 finished with value: 73.49838315006812 and parameters: {'n_estimators': 126, 'learning_rate': 0.547205295426525, 'max_depth': 5, 'max_features': 18}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:49,846] Trial 11 finished with value: 85.01826752800247 and parameters: {'n_estimators': 180, 'learning_rate': 1.0397510619787989, 'max_depth': 9, 'max_features': 20}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:49,974] Trial 12 finished with value: 117.92967169528126 and parameters: {'n_estimators': 170, 'learning_rate': 1.2382195803374003, 'max_depth': 11, 'max_features': 18}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:50,015] Trial 1 finished with value: 84.59861912624484 and parameters: {'n_estimators': 271, 'learning_rate': 1.145501392637296, 'max_depth': 9, 'max_features': 20}. Best is trial 6 with value: 69.22308821928607.
# [I 2021-07-16 12:03:51,027] Trial 13 finished with value: 62.751935615989254 and parameters: {'n_estimators': 324, 'learning_rate': 0.4827902462900875, 'max_depth': 11, 'max_features': 12}. Best is trial 13 with value: 62.751935615989254.
# [I 2021-07-16 12:03:51,143] Trial 18 finished with value: 61.72557449913248 and parameters: {'n_estimators': 239, 'learning_rate': 0.057799431922690214, 'max_depth': 20, 'max_features': 10}. Best is trial 18 with value: 61.72557449913248.
# [I 2021-07-16 12:03:51,525] Trial 17 finished with value: 53.73589121447697 and parameters: {'n_estimators': 330, 'learning_rate': 0.339844992191932, 'max_depth': 14, 'max_features': 9}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:51,565] Trial 10 finished with value: 94.08533698728847 and parameters: {'n_estimators': 308, 'learning_rate': 1.3088491573508045, 'max_depth': 11, 'max_features': 24}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:51,856] Trial 22 finished with value: 74.0183393224703 and parameters: {'n_estimators': 369, 'learning_rate': 0.0983316518551669, 'max_depth': 2, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:52,075] Trial 21 finished with value: 58.27342700477908 and parameters: {'n_estimators': 371, 'learning_rate': 0.5074735363762586, 'max_depth': 20, 'max_features': 12}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:52,343] Trial 20 finished with value: 66.59482118322764 and parameters: {'n_estimators': 322, 'learning_rate': 0.40474488423147087, 'max_depth': 20, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:52,393] Trial 19 finished with value: 62.48348352033612 and parameters: {'n_estimators': 334, 'learning_rate': 0.03465582659053157, 'max_depth': 20, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:53,636] Trial 26 finished with value: 61.07656055416498 and parameters: {'n_estimators': 236, 'learning_rate': 0.08813856398977438, 'max_depth': 15, 'max_features': 10}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:53,950] Trial 23 finished with value: 60.283532853438416 and parameters: {'n_estimators': 345, 'learning_rate': 0.06818175243066282, 'max_depth': 14, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,012] Trial 16 finished with value: 124.73590295022606 and parameters: {'n_estimators': 477, 'learning_rate': 1.6197831592339305, 'max_depth': 18, 'max_features': 16}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,111] Trial 28 finished with value: 63.94727504967713 and parameters: {'n_estimators': 217, 'learning_rate': 0.2408622826809783, 'max_depth': 15, 'max_features': 9}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,183] Trial 29 finished with value: 61.53762888150273 and parameters: {'n_estimators': 224, 'learning_rate': 0.24500645940349317, 'max_depth': 15, 'max_features': 9}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,303] Trial 24 finished with value: 86.013028481038 and parameters: {'n_estimators': 347, 'learning_rate': 0.001289038848679036, 'max_depth': 15, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,557] Trial 25 finished with value: 60.3843835690216 and parameters: {'n_estimators': 378, 'learning_rate': 0.029159437064464222, 'max_depth': 16, 'max_features': 11}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:54,993] Trial 27 finished with value: 67.14713986739207 and parameters: {'n_estimators': 413, 'learning_rate': 0.3996301314777367, 'max_depth': 14, 'max_features': 9}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:55,726] Trial 30 finished with value: 58.212310559808344 and parameters: {'n_estimators': 428, 'learning_rate': 0.2865241058235045, 'max_depth': 15, 'max_features': 8}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:55,832] Trial 31 finished with value: 61.959140843513055 and parameters: {'n_estimators': 438, 'learning_rate': 0.3031644086196398, 'max_depth': 14, 'max_features': 8}. Best is trial 17 with value: 53.73589121447697.
# [I 2021-07-16 12:03:55,839] A new study created in memory with name: optuna_RandomForest
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:03:57,463] Trial 6 finished with value: 59.3016863325195 and parameters: {'n_estimators': 105, 'max_depth': 10, 'max_features': 5}. Best is trial 6 with value: 59.3016863325195.
# [I 2021-07-16 12:03:58,152] Trial 8 finished with value: 61.41253054172949 and parameters: {'n_estimators': 104, 'max_depth': 5, 'max_features': 8}. Best is trial 6 with value: 59.3016863325195.
# [I 2021-07-16 12:03:58,310] Trial 3 finished with value: 59.730237732110155 and parameters: {'n_estimators': 228, 'max_depth': 4, 'max_features': 12}. Best is trial 6 with value: 59.3016863325195.
# [I 2021-07-16 12:03:58,787] Trial 7 finished with value: 62.24156475208071 and parameters: {'n_estimators': 258, 'max_depth': 10, 'max_features': 3}. Best is trial 6 with value: 59.3016863325195.
# [I 2021-07-16 12:03:58,866] Trial 4 finished with value: 59.9931245598065 and parameters: {'n_estimators': 231, 'max_depth': 5, 'max_features': 21}. Best is trial 6 with value: 59.3016863325195.
# [I 2021-07-16 12:03:59,462] Trial 0 finished with value: 59.25904736807295 and parameters: {'n_estimators': 322, 'max_depth': 4, 'max_features': 17}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:03:59,854] Trial 1 finished with value: 61.63657154649113 and parameters: {'n_estimators': 338, 'max_depth': 9, 'max_features': 5}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:00,123] Trial 10 finished with value: 61.29196707860749 and parameters: {'n_estimators': 188, 'max_depth': 3, 'max_features': 18}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:00,275] Trial 5 finished with value: 59.672186185166794 and parameters: {'n_estimators': 299, 'max_depth': 10, 'max_features': 12}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:00,454] Trial 11 finished with value: 62.36565175714074 and parameters: {'n_estimators': 167, 'max_depth': 3, 'max_features': 11}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:01,055] Trial 16 finished with value: 65.81976699064475 and parameters: {'n_estimators': 108, 'max_depth': 2, 'max_features': 24}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:01,307] Trial 9 finished with value: 59.35490678074992 and parameters: {'n_estimators': 169, 'max_depth': 10, 'max_features': 22}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:01,767] Trial 15 finished with value: 67.01989547079503 and parameters: {'n_estimators': 198, 'max_depth': 3, 'max_features': 6}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:02,436] Trial 2 finished with value: 60.29854753765882 and parameters: {'n_estimators': 492, 'max_depth': 9, 'max_features': 8}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:02,975] Trial 13 finished with value: 59.82239253889165 and parameters: {'n_estimators': 255, 'max_depth': 9, 'max_features': 8}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:03,621] Trial 12 finished with value: 59.89986988447415 and parameters: {'n_estimators': 386, 'max_depth': 6, 'max_features': 12}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:05,064] Trial 14 finished with value: 60.51826732669279 and parameters: {'n_estimators': 454, 'max_depth': 9, 'max_features': 7}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:05,580] Trial 18 finished with value: 59.88897087706568 and parameters: {'n_estimators': 406, 'max_depth': 7, 'max_features': 17}. Best is trial 0 with value: 59.25904736807295.
# [I 2021-07-16 12:04:05,740] Trial 17 finished with value: 58.97812554815398 and parameters: {'n_estimators': 445, 'max_depth': 7, 'max_features': 17}. Best is trial 17 with value: 58.97812554815398.
# [I 2021-07-16 12:04:06,344] Trial 19 finished with value: 59.54455695598381 and parameters: {'n_estimators': 445, 'max_depth': 7, 'max_features': 18}. Best is trial 17 with value: 58.97812554815398.
# [I 2021-07-16 12:04:06,761] Trial 21 finished with value: 58.978284141052974 and parameters: {'n_estimators': 387, 'max_depth': 7, 'max_features': 16}. Best is trial 17 with value: 58.97812554815398.
# [I 2021-07-16 12:04:06,854] Trial 20 finished with value: 58.87247171696586 and parameters: {'n_estimators': 452, 'max_depth': 7, 'max_features': 17}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:07,518] Trial 22 finished with value: 59.260359971730175 and parameters: {'n_estimators': 392, 'max_depth': 7, 'max_features': 16}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:08,327] Trial 23 finished with value: 58.94995291199521 and parameters: {'n_estimators': 412, 'max_depth': 7, 'max_features': 16}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:09,448] Trial 25 finished with value: 60.08563456438934 and parameters: {'n_estimators': 332, 'max_depth': 7, 'max_features': 16}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:09,618] Trial 24 finished with value: 59.48176274436381 and parameters: {'n_estimators': 387, 'max_depth': 7, 'max_features': 16}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:09,829] Trial 27 finished with value: 59.65917372149044 and parameters: {'n_estimators': 331, 'max_depth': 7, 'max_features': 15}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:09,973] Trial 26 finished with value: 59.29048006142447 and parameters: {'n_estimators': 400, 'max_depth': 7, 'max_features': 16}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:10,155] Trial 28 finished with value: 59.04414709847879 and parameters: {'n_estimators': 352, 'max_depth': 7, 'max_features': 15}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:10,562] Trial 29 finished with value: 59.63074543941657 and parameters: {'n_estimators': 484, 'max_depth': 7, 'max_features': 14}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:10,788] Trial 30 finished with value: 59.34633157361398 and parameters: {'n_estimators': 495, 'max_depth': 8, 'max_features': 15}. Best is trial 20 with value: 58.87247171696586.
# [I 2021-07-16 12:04:10,892] Trial 31 finished with value: 59.71479458702556 and parameters: {'n_estimators': 483, 'max_depth': 8, 'max_features': 14}. Best is trial 20 with value: 58.87247171696586.
# Training Gradient Boosting Model
# [I 2021-07-16 12:04:37,284] A new study created in memory with name: optuna_GradientBoostingRegressor
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:04:37,397] Trial 2 finished with value: 78.18829828629637 and parameters: {'n_estimators': 17, 'learning_rate': 0.952587469189363, 'max_depth': 5, 'max_features': 10}. Best is trial 2 with value: 78.18829828629637.
# 91 features with zero importance after one-hot encoding.
#
# 15 features required for cumulative importance of 0.90 after one hot encoding.
# 106 features do not contribute to cumulative importance of 0.90.
#
# 3
# [I 2021-07-16 12:04:37,509] Trial 0 finished with value: 82.80656959552178 and parameters: {'n_estimators': 31, 'learning_rate': 0.8384873805189279, 'max_depth': 8, 'max_features': 12}. Best is trial 2 with value: 78.18829828629637.
# [I 2021-07-16 12:04:37,646] Trial 6 finished with value: 135.12989009309513 and parameters: {'n_estimators': 45, 'learning_rate': 1.8404106176655781, 'max_depth': 13, 'max_features': 13}. Best is trial 2 with value: 78.18829828629637.
# [I 2021-07-16 12:04:37,828] Trial 5 finished with value: 164.09813268259518 and parameters: {'n_estimators': 164, 'learning_rate': 1.683509481521464, 'max_depth': 7, 'max_features': 3}. Best is trial 2 with value: 78.18829828629637.
# [I 2021-07-16 12:04:37,926] Trial 11 finished with value: 74.08797572929467 and parameters: {'n_estimators': 18, 'learning_rate': 0.3032146657072856, 'max_depth': 17, 'max_features': 8}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,225] Trial 12 finished with value: 85.34546182520424 and parameters: {'n_estimators': 57, 'learning_rate': 1.2004758928596322, 'max_depth': 15, 'max_features': 8}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,270] Trial 7 finished with value: 81.3118853212277 and parameters: {'n_estimators': 235, 'learning_rate': 0.8176796609111285, 'max_depth': 20, 'max_features': 7}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,306] Trial 13 finished with value: 130.28616070976352 and parameters: {'n_estimators': 12, 'learning_rate': 1.6875962987073654, 'max_depth': 5, 'max_features': 14}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,516] Trial 8 finished with value: 185.04684679979064 and parameters: {'n_estimators': 169, 'learning_rate': 1.8693392083068927, 'max_depth': 9, 'max_features': 14}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,666] Trial 1 finished with value: 85.49146786055093 and parameters: {'n_estimators': 172, 'learning_rate': 0.8650921011018835, 'max_depth': 14, 'max_features': 14}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,821] Trial 10 finished with value: 98.32105580696746 and parameters: {'n_estimators': 275, 'learning_rate': 1.4798358041794, 'max_depth': 9, 'max_features': 6}. Best is trial 11 with value: 74.08797572929467.
# [I 2021-07-16 12:04:38,893] Trial 4 finished with value: 73.36795494939099 and parameters: {'n_estimators': 328, 'learning_rate': 0.4095071490931599, 'max_depth': 7, 'max_features': 10}. Best is trial 4 with value: 73.36795494939099.
# [I 2021-07-16 12:04:38,994] Trial 3 finished with value: 65.91474996696553 and parameters: {'n_estimators': 418, 'learning_rate': 0.7046729913007976, 'max_depth': 20, 'max_features': 10}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:39,588] Trial 9 finished with value: 81.08383457596891 and parameters: {'n_estimators': 409, 'learning_rate': 0.772830866254149, 'max_depth': 15, 'max_features': 14}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:39,913] Trial 20 finished with value: 78.35538405822389 and parameters: {'n_estimators': 412, 'learning_rate': 0.2704599656928228, 'max_depth': 2, 'max_features': 11}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:39,958] Trial 14 finished with value: 76.41585373017936 and parameters: {'n_estimators': 460, 'learning_rate': 0.3499468074283012, 'max_depth': 7, 'max_features': 3}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:39,964] Trial 18 finished with value: 74.57136080309277 and parameters: {'n_estimators': 473, 'learning_rate': 0.14727915295431337, 'max_depth': 2, 'max_features': 10}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:40,307] Trial 16 finished with value: 75.05060385941152 and parameters: {'n_estimators': 235, 'learning_rate': 0.6578707874170584, 'max_depth': 11, 'max_features': 11}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:40,598] Trial 21 finished with value: 73.94239889328308 and parameters: {'n_estimators': 476, 'learning_rate': 0.29442781414096647, 'max_depth': 2, 'max_features': 11}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:41,051] Trial 17 finished with value: 67.66271252460315 and parameters: {'n_estimators': 451, 'learning_rate': 0.01176799898811104, 'max_depth': 20, 'max_features': 4}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:41,467] Trial 15 finished with value: 89.67306625618436 and parameters: {'n_estimators': 460, 'learning_rate': 0.7015723484474943, 'max_depth': 8, 'max_features': 15}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:41,570] Trial 25 finished with value: 78.87438295548971 and parameters: {'n_estimators': 323, 'learning_rate': 0.557245971285657, 'max_depth': 20, 'max_features': 5}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:41,979] Trial 27 finished with value: 76.91263978549317 and parameters: {'n_estimators': 372, 'learning_rate': 1.1858885288302863, 'max_depth': 20, 'max_features': 5}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:42,132] Trial 24 finished with value: 79.37788663956724 and parameters: {'n_estimators': 337, 'learning_rate': 0.6002032656133153, 'max_depth': 20, 'max_features': 16}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:42,229] Trial 23 finished with value: 74.0019391253102 and parameters: {'n_estimators': 349, 'learning_rate': 0.5680813486028313, 'max_depth': 20, 'max_features': 16}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:42,423] Trial 19 finished with value: 71.01051835268373 and parameters: {'n_estimators': 458, 'learning_rate': 0.13235179632506433, 'max_depth': 19, 'max_features': 10}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:42,645] Trial 26 finished with value: 79.064466052502 and parameters: {'n_estimators': 318, 'learning_rate': 0.5632553748268134, 'max_depth': 20, 'max_features': 16}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:42,733] Trial 28 finished with value: 70.11587250525216 and parameters: {'n_estimators': 343, 'learning_rate': 0.5113348530428177, 'max_depth': 20, 'max_features': 5}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:43,399] Trial 29 finished with value: 73.10972555776726 and parameters: {'n_estimators': 364, 'learning_rate': 0.47309553876640476, 'max_depth': 19, 'max_features': 8}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:43,548] Trial 30 finished with value: 68.76714206094503 and parameters: {'n_estimators': 370, 'learning_rate': 0.00796972749361322, 'max_depth': 17, 'max_features': 8}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:43,625] Trial 22 finished with value: 74.12469346132303 and parameters: {'n_estimators': 497, 'learning_rate': 0.48017759294992024, 'max_depth': 11, 'max_features': 16}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:43,762] Trial 31 finished with value: 68.33022877103627 and parameters: {'n_estimators': 403, 'learning_rate': 0.031058222508720996, 'max_depth': 18, 'max_features': 9}. Best is trial 3 with value: 65.91474996696553.
# [I 2021-07-16 12:04:43,767] A new study created in memory with name: optuna_RandomForest
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:04:46,253] Trial 7 finished with value: 62.417334776319215 and parameters: {'n_estimators': 148, 'max_depth': 6, 'max_features': 14}. Best is trial 7 with value: 62.417334776319215.
# [I 2021-07-16 12:04:46,851] Trial 6 finished with value: 63.617831554000354 and parameters: {'n_estimators': 192, 'max_depth': 7, 'max_features': 6}. Best is trial 7 with value: 62.417334776319215.
# [I 2021-07-16 12:04:47,391] Trial 8 finished with value: 60.417004807882954 and parameters: {'n_estimators': 143, 'max_depth': 2, 'max_features': 15}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:47,752] Trial 3 finished with value: 61.02567660946893 and parameters: {'n_estimators': 360, 'max_depth': 3, 'max_features': 8}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:48,157] Trial 0 finished with value: 61.51501832283428 and parameters: {'n_estimators': 477, 'max_depth': 2, 'max_features': 11}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:48,677] Trial 5 finished with value: 63.44764438186767 and parameters: {'n_estimators': 277, 'max_depth': 7, 'max_features': 8}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:49,223] Trial 4 finished with value: 64.44532714119565 and parameters: {'n_estimators': 302, 'max_depth': 8, 'max_features': 10}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:49,867] Trial 9 finished with value: 63.90044948023631 and parameters: {'n_estimators': 197, 'max_depth': 7, 'max_features': 7}. Best is trial 8 with value: 60.417004807882954.
# [I 2021-07-16 12:04:50,186] Trial 10 finished with value: 60.042728514633204 and parameters: {'n_estimators': 246, 'max_depth': 3, 'max_features': 16}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:50,578] Trial 1 finished with value: 63.94010636559979 and parameters: {'n_estimators': 381, 'max_depth': 8, 'max_features': 15}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:51,046] Trial 2 finished with value: 63.78653619793084 and parameters: {'n_estimators': 442, 'max_depth': 9, 'max_features': 8}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:51,392] Trial 12 finished with value: 64.94539879364562 and parameters: {'n_estimators': 471, 'max_depth': 3, 'max_features': 4}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:51,772] Trial 15 finished with value: 63.45464659946292 and parameters: {'n_estimators': 147, 'max_depth': 8, 'max_features': 14}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:52,068] Trial 18 finished with value: 61.12697273704115 and parameters: {'n_estimators': 109, 'max_depth': 4, 'max_features': 16}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:52,213] Trial 16 finished with value: 61.513176363732875 and parameters: {'n_estimators': 177, 'max_depth': 5, 'max_features': 13}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:52,700] Trial 19 finished with value: 60.423766519724964 and parameters: {'n_estimators': 123, 'max_depth': 4, 'max_features': 16}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:52,990] Trial 13 finished with value: 62.852630629752504 and parameters: {'n_estimators': 327, 'max_depth': 7, 'max_features': 14}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:53,733] Trial 11 finished with value: 63.64874094949161 and parameters: {'n_estimators': 383, 'max_depth': 9, 'max_features': 10}. Best is trial 10 with value: 60.042728514633204.
# [I 2021-07-16 12:04:54,258] Trial 22 finished with value: 59.43254945931417 and parameters: {'n_estimators': 285, 'max_depth': 2, 'max_features': 16}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:54,450] Trial 23 finished with value: 60.463605564333655 and parameters: {'n_estimators': 243, 'max_depth': 2, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:54,623] Trial 20 finished with value: 60.971970229325095 and parameters: {'n_estimators': 236, 'max_depth': 4, 'max_features': 16}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:54,837] Trial 14 finished with value: 65.11871412564317 and parameters: {'n_estimators': 352, 'max_depth': 10, 'max_features': 14}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:54,998] Trial 24 finished with value: 60.11951588806259 and parameters: {'n_estimators': 245, 'max_depth': 2, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:55,197] Trial 21 finished with value: 60.52087847507159 and parameters: {'n_estimators': 247, 'max_depth': 4, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:55,495] Trial 17 finished with value: 65.14566089925174 and parameters: {'n_estimators': 499, 'max_depth': 4, 'max_features': 3}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,042] Trial 25 finished with value: 60.84389068458216 and parameters: {'n_estimators': 246, 'max_depth': 2, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,349] Trial 26 finished with value: 61.043716121886646 and parameters: {'n_estimators': 249, 'max_depth': 2, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,500] Trial 28 finished with value: 59.537649618027366 and parameters: {'n_estimators': 269, 'max_depth': 2, 'max_features': 16}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,588] Trial 29 finished with value: 59.53715507218416 and parameters: {'n_estimators': 252, 'max_depth': 2, 'max_features': 16}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,725] Trial 27 finished with value: 60.11676322233381 and parameters: {'n_estimators': 250, 'max_depth': 3, 'max_features': 16}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,796] Trial 30 finished with value: 60.04767767146571 and parameters: {'n_estimators': 272, 'max_depth': 3, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# [I 2021-07-16 12:04:56,813] Trial 31 finished with value: 60.198419675421384 and parameters: {'n_estimators': 277, 'max_depth': 3, 'max_features': 12}. Best is trial 22 with value: 59.43254945931417.
# Training Gradient Boosting Model
# [I 2021-07-16 12:05:19,671] A new study created in memory with name: optuna_GradientBoostingRegressor
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:05:19,812] Trial 4 finished with value: 85.09629924314856 and parameters: {'n_estimators': 12, 'learning_rate': 0.6582610366196524, 'max_depth': 18, 'max_features': 4}. Best is trial 4 with value: 85.09629924314856.
# 80 features with zero importance after one-hot encoding.
#
# 22 features required for cumulative importance of 0.90 after one hot encoding.
# 99 features do not contribute to cumulative importance of 0.90.
#
# 4
# [I 2021-07-16 12:05:20,008] Trial 1 finished with value: 80.95456689759013 and parameters: {'n_estimators': 67, 'learning_rate': 0.22705298432986476, 'max_depth': 4, 'max_features': 10}. Best is trial 1 with value: 80.95456689759013.
# [I 2021-07-16 12:05:20,188] Trial 5 finished with value: 101.57173444539106 and parameters: {'n_estimators': 202, 'learning_rate': 0.4640774903428122, 'max_depth': 3, 'max_features': 4}. Best is trial 1 with value: 80.95456689759013.
# [I 2021-07-16 12:05:20,632] Trial 3 finished with value: 145.68287517241447 and parameters: {'n_estimators': 189, 'learning_rate': 1.5424269538260913, 'max_depth': 5, 'max_features': 13}. Best is trial 1 with value: 80.95456689759013.
# [I 2021-07-16 12:05:20,876] Trial 8 finished with value: 77.78238416256521 and parameters: {'n_estimators': 152, 'learning_rate': 0.15261284000404118, 'max_depth': 9, 'max_features': 13}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,182] Trial 10 finished with value: 87.31905886735933 and parameters: {'n_estimators': 350, 'learning_rate': 0.5265331223773899, 'max_depth': 2, 'max_features': 22}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,238] Trial 7 finished with value: 78.61667044621095 and parameters: {'n_estimators': 298, 'learning_rate': 0.17777129269704894, 'max_depth': 5, 'max_features': 15}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,300] Trial 0 finished with value: 496.9961223569492 and parameters: {'n_estimators': 390, 'learning_rate': 1.976626256079826, 'max_depth': 5, 'max_features': 10}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,421] Trial 6 finished with value: 95.69235498507494 and parameters: {'n_estimators': 221, 'learning_rate': 0.346204762962935, 'max_depth': 19, 'max_features': 13}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,510] Trial 2 finished with value: 332.8819169580025 and parameters: {'n_estimators': 432, 'learning_rate': 1.914059600882963, 'max_depth': 4, 'max_features': 14}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:21,835] Trial 11 finished with value: 385.80890926690387 and parameters: {'n_estimators': 228, 'learning_rate': 1.8792486377909756, 'max_depth': 8, 'max_features': 8}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,006] Trial 9 finished with value: 146.6877328555004 and parameters: {'n_estimators': 192, 'learning_rate': 1.5352791850254766, 'max_depth': 15, 'max_features': 17}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,056] Trial 12 finished with value: 132.7292706602062 and parameters: {'n_estimators': 230, 'learning_rate': 1.2144458548558539, 'max_depth': 6, 'max_features': 10}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,134] Trial 13 finished with value: 102.52868228078357 and parameters: {'n_estimators': 176, 'learning_rate': 1.2746787448595096, 'max_depth': 4, 'max_features': 17}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,548] Trial 17 finished with value: 116.09476238588836 and parameters: {'n_estimators': 107, 'learning_rate': 1.1032070974123491, 'max_depth': 10, 'max_features': 19}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,763] Trial 14 finished with value: 113.63139105368468 and parameters: {'n_estimators': 309, 'learning_rate': 1.1510087199319743, 'max_depth': 20, 'max_features': 18}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,944] Trial 19 finished with value: 81.31047779585491 and parameters: {'n_estimators': 99, 'learning_rate': 0.07756179363337623, 'max_depth': 12, 'max_features': 19}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:22,955] Trial 18 finished with value: 103.2841506081692 and parameters: {'n_estimators': 124, 'learning_rate': 0.005073691023321225, 'max_depth': 12, 'max_features': 18}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:23,013] Trial 20 finished with value: 123.927222264143 and parameters: {'n_estimators': 113, 'learning_rate': 0.0006425041365157591, 'max_depth': 10, 'max_features': 18}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:23,369] Trial 16 finished with value: 120.00553417456896 and parameters: {'n_estimators': 266, 'learning_rate': 1.3968305070348492, 'max_depth': 15, 'max_features': 18}. Best is trial 8 with value: 77.78238416256521.
# [I 2021-07-16 12:05:23,526] Trial 15 finished with value: 75.40127236413474 and parameters: {'n_estimators': 216, 'learning_rate': 0.2360837192976577, 'max_depth': 14, 'max_features': 16}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:24,592] Trial 27 finished with value: 125.09805513676402 and parameters: {'n_estimators': 297, 'learning_rate': 0.7346581815849974, 'max_depth': 8, 'max_features': 7}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:24,797] Trial 21 finished with value: 83.30083669261217 and parameters: {'n_estimators': 304, 'learning_rate': 0.026250382824344498, 'max_depth': 11, 'max_features': 18}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:24,965] Trial 24 finished with value: 81.18166167980736 and parameters: {'n_estimators': 295, 'learning_rate': 0.7798129078471773, 'max_depth': 8, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:25,022] Trial 26 finished with value: 112.44374757270982 and parameters: {'n_estimators': 295, 'learning_rate': 0.8299961188264122, 'max_depth': 8, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:25,132] Trial 25 finished with value: 88.94499956966959 and parameters: {'n_estimators': 286, 'learning_rate': 0.8023510058341352, 'max_depth': 9, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:25,321] Trial 22 finished with value: 81.52167077904593 and parameters: {'n_estimators': 337, 'learning_rate': 0.04003259990244168, 'max_depth': 14, 'max_features': 16}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:25,579] Trial 28 finished with value: 112.3816731226346 and parameters: {'n_estimators': 334, 'learning_rate': 0.7717631493675375, 'max_depth': 8, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:25,873] Trial 31 finished with value: 77.12705845464521 and parameters: {'n_estimators': 156, 'learning_rate': 0.2243026780650017, 'max_depth': 15, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:26,371] Trial 29 finished with value: 83.66430045432439 and parameters: {'n_estimators': 283, 'learning_rate': 0.221160192503676, 'max_depth': 15, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:27,016] Trial 23 finished with value: 77.31620683003351 and parameters: {'n_estimators': 495, 'learning_rate': 0.07170556236113657, 'max_depth': 13, 'max_features': 21}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:27,286] Trial 30 finished with value: 90.86285458401431 and parameters: {'n_estimators': 488, 'learning_rate': 0.22944638483191143, 'max_depth': 15, 'max_features': 15}. Best is trial 15 with value: 75.40127236413474.
# [I 2021-07-16 12:05:27,290] A new study created in memory with name: optuna_RandomForest
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:05:29,433] Trial 6 finished with value: 69.01984742782535 and parameters: {'n_estimators': 182, 'max_depth': 8, 'max_features': 5}. Best is trial 6 with value: 69.01984742782535.
# [I 2021-07-16 12:05:29,738] Trial 7 finished with value: 68.59263256150743 and parameters: {'n_estimators': 309, 'max_depth': 4, 'max_features': 3}. Best is trial 7 with value: 68.59263256150743.
# [I 2021-07-16 12:05:30,085] Trial 4 finished with value: 67.38300170428082 and parameters: {'n_estimators': 257, 'max_depth': 4, 'max_features': 11}. Best is trial 4 with value: 67.38300170428082.
# [I 2021-07-16 12:05:30,306] Trial 8 finished with value: 71.18322007097713 and parameters: {'n_estimators': 111, 'max_depth': 2, 'max_features': 13}. Best is trial 4 with value: 67.38300170428082.
# [I 2021-07-16 12:05:30,682] Trial 1 finished with value: 68.69858914548485 and parameters: {'n_estimators': 287, 'max_depth': 7, 'max_features': 5}. Best is trial 4 with value: 67.38300170428082.
# [I 2021-07-16 12:05:30,831] Trial 0 finished with value: 71.9499593616511 and parameters: {'n_estimators': 252, 'max_depth': 7, 'max_features': 10}. Best is trial 4 with value: 67.38300170428082.
# [I 2021-07-16 12:05:31,901] Trial 2 finished with value: 70.1527025766746 and parameters: {'n_estimators': 388, 'max_depth': 8, 'max_features': 4}. Best is trial 4 with value: 67.38300170428082.
# [I 2021-07-16 12:05:32,343] Trial 11 finished with value: 66.2913731672699 and parameters: {'n_estimators': 240, 'max_depth': 3, 'max_features': 11}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:32,951] Trial 5 finished with value: 74.78385522366753 and parameters: {'n_estimators': 376, 'max_depth': 9, 'max_features': 14}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:33,388] Trial 3 finished with value: 74.16430677531281 and parameters: {'n_estimators': 389, 'max_depth': 9, 'max_features': 14}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:33,746] Trial 9 finished with value: 70.2298536396352 and parameters: {'n_estimators': 305, 'max_depth': 7, 'max_features': 7}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:33,989] Trial 12 finished with value: 74.42338655893002 and parameters: {'n_estimators': 211, 'max_depth': 8, 'max_features': 19}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:34,175] Trial 10 finished with value: 66.53828503086984 and parameters: {'n_estimators': 471, 'max_depth': 3, 'max_features': 7}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:34,997] Trial 20 finished with value: 73.83619468771134 and parameters: {'n_estimators': 142, 'max_depth': 2, 'max_features': 8}. Best is trial 11 with value: 66.2913731672699.
# [I 2021-07-16 12:05:35,274] Trial 13 finished with value: 66.12391330372469 and parameters: {'n_estimators': 453, 'max_depth': 3, 'max_features': 16}. Best is trial 13 with value: 66.12391330372469.
# [I 2021-07-16 12:05:35,728] Trial 19 finished with value: 66.07125898932411 and parameters: {'n_estimators': 134, 'max_depth': 4, 'max_features': 10}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:35,939] Trial 15 finished with value: 71.15142527513449 and parameters: {'n_estimators': 211, 'max_depth': 10, 'max_features': 8}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:36,232] Trial 16 finished with value: 73.02247636782543 and parameters: {'n_estimators': 165, 'max_depth': 10, 'max_features': 8}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:36,938] Trial 18 finished with value: 68.82693198785836 and parameters: {'n_estimators': 199, 'max_depth': 4, 'max_features': 21}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:37,346] Trial 14 finished with value: 68.79542462141522 and parameters: {'n_estimators': 397, 'max_depth': 6, 'max_features': 3}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:38,011] Trial 17 finished with value: 70.33234121351202 and parameters: {'n_estimators': 482, 'max_depth': 2, 'max_features': 20}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:39,011] Trial 28 finished with value: 70.47836712839887 and parameters: {'n_estimators': 116, 'max_depth': 5, 'max_features': 17}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:40,443] Trial 21 finished with value: 68.38818030532974 and parameters: {'n_estimators': 496, 'max_depth': 4, 'max_features': 16}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:40,936] Trial 23 finished with value: 71.86316039826676 and parameters: {'n_estimators': 442, 'max_depth': 5, 'max_features': 18}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:41,129] Trial 22 finished with value: 69.86269163782694 and parameters: {'n_estimators': 474, 'max_depth': 5, 'max_features': 18}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:41,469] Trial 25 finished with value: 70.73436687242771 and parameters: {'n_estimators': 471, 'max_depth': 5, 'max_features': 17}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:41,603] Trial 24 finished with value: 69.43811598700545 and parameters: {'n_estimators': 494, 'max_depth': 5, 'max_features': 18}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:41,698] Trial 29 finished with value: 66.68093866918659 and parameters: {'n_estimators': 342, 'max_depth': 3, 'max_features': 16}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:41,970] Trial 26 finished with value: 71.09237120577335 and parameters: {'n_estimators': 498, 'max_depth': 5, 'max_features': 16}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:42,082] Trial 27 finished with value: 69.26804624032259 and parameters: {'n_estimators': 498, 'max_depth': 5, 'max_features': 17}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:42,322] Trial 31 finished with value: 66.74165127662296 and parameters: {'n_estimators': 340, 'max_depth': 3, 'max_features': 11}. Best is trial 19 with value: 66.07125898932411.
# [I 2021-07-16 12:05:42,413] Trial 30 finished with value: 65.85783654810135 and parameters: {'n_estimators': 438, 'max_depth': 3, 'max_features': 11}. Best is trial 30 with value: 65.85783654810135.
# Training Gradient Boosting Model
# [I 2021-07-16 12:06:01,630] A new study created in memory with name: optuna_GradientBoostingRegressor
# 91 features with zero importance after one-hot encoding.
#
# 15 features required for cumulative importance of 0.90 after one hot encoding.
# 106 features do not contribute to cumulative importance of 0.90.
#
# 5
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:06:01,924] Trial 3 finished with value: 89.27899713901505 and parameters: {'n_estimators': 33, 'learning_rate': 0.48842417763532997, 'max_depth': 10, 'max_features': 13}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:01,968] Trial 2 finished with value: 100.40339719493295 and parameters: {'n_estimators': 41, 'learning_rate': 1.0020875187886993, 'max_depth': 13, 'max_features': 8}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:02,214] Trial 0 finished with value: 90.36904134957075 and parameters: {'n_estimators': 159, 'learning_rate': 0.09805467308853211, 'max_depth': 5, 'max_features': 7}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:02,387] Trial 6 finished with value: 101.96135692334464 and parameters: {'n_estimators': 106, 'learning_rate': 0.6356386698982979, 'max_depth': 11, 'max_features': 10}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:02,426] Trial 1 finished with value: 112.56354840905313 and parameters: {'n_estimators': 282, 'learning_rate': 1.2661200310926166, 'max_depth': 4, 'max_features': 6}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:02,795] Trial 5 finished with value: 93.22443968007511 and parameters: {'n_estimators': 221, 'learning_rate': 0.4298916982661356, 'max_depth': 6, 'max_features': 13}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:02,931] Trial 13 finished with value: 118.16996904912018 and parameters: {'n_estimators': 55, 'learning_rate': 1.7759419635446985, 'max_depth': 2, 'max_features': 15}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:03,391] Trial 4 finished with value: 118.60251391583972 and parameters: {'n_estimators': 295, 'learning_rate': 1.021031462848144, 'max_depth': 8, 'max_features': 12}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:03,706] Trial 10 finished with value: 93.91579996594736 and parameters: {'n_estimators': 464, 'learning_rate': 0.7947459324276882, 'max_depth': 5, 'max_features': 7}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:03,865] Trial 12 finished with value: 96.62574797608445 and parameters: {'n_estimators': 389, 'learning_rate': 0.9567373106885286, 'max_depth': 8, 'max_features': 5}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:04,045] Trial 17 finished with value: 90.2948906392554 and parameters: {'n_estimators': 21, 'learning_rate': 0.02634409821116218, 'max_depth': 20, 'max_features': 16}. Best is trial 3 with value: 89.27899713901505.
# [I 2021-07-16 12:06:04,138] Trial 15 finished with value: 111.6392785286262 and parameters: {'n_estimators': 277, 'learning_rate': 0.9716653547019585, 'max_depth': 18, 'max_features': 9}. Best is trial 3 with value: 89.27899713901505.
# ...
# [I 2021-07-16 12:09:46,491] Trial 9 finished with value: 57.40551420821372 and parameters: {'n_estimators': 197, 'learning_rate': 1.3074396930429646, 'max_depth': 13, 'max_features': 10}. Best is trial 9 with value: 57.40551420821372.
# [I 2021-07-16 12:09:46,736] Trial 15 finished with value: 66.85901893580466 and parameters: {'n_estimators': 94, 'learning_rate': 0.34911638602356465, 'max_depth': 6, 'max_features': 8}. Best is trial 9 with value: 57.40551420821372.
# [I 2021-07-16 12:09:46,811] Trial 11 finished with value: 56.62051448455859 and parameters: {'n_estimators': 476, 'learning_rate': 0.1621005568963647, 'max_depth': 6, 'max_features': 3}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:47,290] Trial 16 finished with value: 72.35040343796358 and parameters: {'n_estimators': 247, 'learning_rate': 1.1267500087093856, 'max_depth': 5, 'max_features': 5}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:47,357] Trial 2 finished with value: 110.49786766065897 and parameters: {'n_estimators': 355, 'learning_rate': 1.3323495753385841, 'max_depth': 4, 'max_features': 23}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:47,683] Trial 12 finished with value: 60.34864072359199 and parameters: {'n_estimators': 364, 'learning_rate': 1.2752192498266384, 'max_depth': 12, 'max_features': 6}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:48,227] Trial 8 finished with value: 152.93522177817653 and parameters: {'n_estimators': 220, 'learning_rate': 1.9131571373308174, 'max_depth': 19, 'max_features': 24}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:48,307] Trial 1 finished with value: 100.91511245716946 and parameters: {'n_estimators': 299, 'learning_rate': 1.6754776940398384, 'max_depth': 12, 'max_features': 17}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:48,522] Trial 17 finished with value: 1372.319058665993 and parameters: {'n_estimators': 325, 'learning_rate': 1.9982576763863473, 'max_depth': 20, 'max_features': 3}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:48,571] Trial 18 finished with value: 446.52017066941727 and parameters: {'n_estimators': 314, 'learning_rate': 1.987994327086714, 'max_depth': 20, 'max_features': 3}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:48,591] Trial 14 finished with value: 65.56634308760529 and parameters: {'n_estimators': 201, 'learning_rate': 0.42028718717088, 'max_depth': 19, 'max_features': 19}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:49,825] Trial 19 finished with value: 224.71188044686386 and parameters: {'n_estimators': 440, 'learning_rate': 1.925372898792294, 'max_depth': 20, 'max_features': 3}. Best is trial 11 with value: 56.62051448455859.
# [I 2021-07-16 12:09:50,065] Trial 20 finished with value: 50.609934077835895 and parameters: {'n_estimators': 478, 'learning_rate': 0.049241040404252256, 'max_depth': 20, 'max_features': 3}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:50,107] Trial 23 finished with value: 56.67062994654674 and parameters: {'n_estimators': 485, 'learning_rate': 0.7883977745453346, 'max_depth': 8, 'max_features': 3}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:50,608] Trial 21 finished with value: 243.24064074357227 and parameters: {'n_estimators': 499, 'learning_rate': 1.952363623102476, 'max_depth': 20, 'max_features': 4}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:50,665] Trial 22 finished with value: 50.789262086271634 and parameters: {'n_estimators': 464, 'learning_rate': 0.032048313186050115, 'max_depth': 9, 'max_features': 4}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:50,737] Trial 24 finished with value: 51.64992467138476 and parameters: {'n_estimators': 500, 'learning_rate': 0.04035383749415067, 'max_depth': 8, 'max_features': 3}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:51,123] Trial 25 finished with value: 51.847275838047054 and parameters: {'n_estimators': 481, 'learning_rate': 0.014715227056898095, 'max_depth': 8, 'max_features': 6}. Best is trial 20 with value: 50.609934077835895.
# [I 2021-07-16 12:09:51,144] Trial 26 finished with value: 49.97637985348455 and parameters: {'n_estimators': 489, 'learning_rate': 0.06742408794221089, 'max_depth': 8, 'max_features': 6}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:51,965] Trial 29 finished with value: 51.65104409605094 and parameters: {'n_estimators': 487, 'learning_rate': 0.027397340978737972, 'max_depth': 8, 'max_features': 5}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:52,058] Trial 28 finished with value: 51.183023871101454 and parameters: {'n_estimators': 489, 'learning_rate': 0.02190681572230127, 'max_depth': 8, 'max_features': 6}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:52,168] Trial 27 finished with value: 53.370371615381586 and parameters: {'n_estimators': 500, 'learning_rate': 0.03177960138878724, 'max_depth': 9, 'max_features': 7}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:52,265] Trial 31 finished with value: 51.38661773721973 and parameters: {'n_estimators': 444, 'learning_rate': 0.012054311230745962, 'max_depth': 9, 'max_features': 6}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:52,322] Trial 30 finished with value: 50.08521332428267 and parameters: {'n_estimators': 495, 'learning_rate': 0.04910938907086669, 'max_depth': 8, 'max_features': 6}. Best is trial 26 with value: 49.97637985348455.
# [I 2021-07-16 12:09:52,330] A new study created in memory with name: optuna_RandomForest
# C:\Users\elena.khotlyannik\Anaconda3\lib\site-packages\optuna\study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# [I 2021-07-16 12:09:55,777] Trial 5 finished with value: 57.42851967485126 and parameters: {'n_estimators': 420, 'max_depth': 3, 'max_features': 5}. Best is trial 5 with value: 57.42851967485126.
# [I 2021-07-16 12:09:56,655] Trial 4 finished with value: 51.78155312448821 and parameters: {'n_estimators': 270, 'max_depth': 9, 'max_features': 7}. Best is trial 4 with value: 51.78155312448821.
# [I 2021-07-16 12:09:56,849] Trial 3 finished with value: 52.3696472632657 and parameters: {'n_estimators': 296, 'max_depth': 5, 'max_features': 16}. Best is trial 4 with value: 51.78155312448821.
# [I 2021-07-16 12:09:57,753] Trial 0 finished with value: 52.640420020422575 and parameters: {'n_estimators': 423, 'max_depth': 4, 'max_features': 19}. Best is trial 4 with value: 51.78155312448821.
# [I 2021-07-16 12:09:57,983] Trial 1 finished with value: 50.99801580475954 and parameters: {'n_estimators': 355, 'max_depth': 10, 'max_features': 10}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:09:58,576] Trial 8 finished with value: 51.611192320754995 and parameters: {'n_estimators': 194, 'max_depth': 10, 'max_features': 4}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:09:59,290] Trial 6 finished with value: 52.278408842707385 and parameters: {'n_estimators': 452, 'max_depth': 5, 'max_features': 16}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:09:59,493] Trial 2 finished with value: 51.81932984462341 and parameters: {'n_estimators': 476, 'max_depth': 8, 'max_features': 4}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:09:59,941] Trial 7 finished with value: 52.19297436945851 and parameters: {'n_estimators': 352, 'max_depth': 9, 'max_features': 25}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:00,913] Trial 10 finished with value: 52.7936873175953 and parameters: {'n_estimators': 185, 'max_depth': 9, 'max_features': 22}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:01,249] Trial 11 finished with value: 52.78699208481964 and parameters: {'n_estimators': 186, 'max_depth': 4, 'max_features': 21}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:02,251] Trial 14 finished with value: 51.43983151552883 and parameters: {'n_estimators': 162, 'max_depth': 9, 'max_features': 15}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:02,472] Trial 12 finished with value: 52.39341994831123 and parameters: {'n_estimators': 364, 'max_depth': 4, 'max_features': 9}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:02,903] Trial 18 finished with value: 52.1241399686756 and parameters: {'n_estimators': 117, 'max_depth': 7, 'max_features': 10}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:03,136] Trial 9 finished with value: 52.00803250142944 and parameters: {'n_estimators': 477, 'max_depth': 4, 'max_features': 12}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:04,036] Trial 19 finished with value: 52.028658010832615 and parameters: {'n_estimators': 128, 'max_depth': 7, 'max_features': 10}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:04,211] Trial 20 finished with value: 52.19631871631587 and parameters: {'n_estimators': 118, 'max_depth': 7, 'max_features': 12}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:04,395] Trial 21 finished with value: 51.002996179824436 and parameters: {'n_estimators': 108, 'max_depth': 10, 'max_features': 13}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:04,774] Trial 22 finished with value: 51.39459857625601 and parameters: {'n_estimators': 105, 'max_depth': 10, 'max_features': 14}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:05,449] Trial 16 finished with value: 51.52905646309165 and parameters: {'n_estimators': 394, 'max_depth': 8, 'max_features': 5}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:05,967] Trial 17 finished with value: 52.46662244728491 and parameters: {'n_estimators': 350, 'max_depth': 7, 'max_features': 10}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:06,442] Trial 13 finished with value: 51.38324350231139 and parameters: {'n_estimators': 480, 'max_depth': 10, 'max_features': 9}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:06,674] Trial 15 finished with value: 53.49610379249539 and parameters: {'n_estimators': 404, 'max_depth': 6, 'max_features': 25}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:08,040] Trial 23 finished with value: 51.840049392892425 and parameters: {'n_estimators': 246, 'max_depth': 10, 'max_features': 13}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:08,271] Trial 26 finished with value: 51.255442721790885 and parameters: {'n_estimators': 253, 'max_depth': 8, 'max_features': 7}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:08,279] Trial 25 finished with value: 52.53990738881363 and parameters: {'n_estimators': 243, 'max_depth': 10, 'max_features': 13}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:08,386] Trial 24 finished with value: 52.08221535500913 and parameters: {'n_estimators': 258, 'max_depth': 10, 'max_features': 14}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:08,757] Trial 27 finished with value: 51.30011939993403 and parameters: {'n_estimators': 239, 'max_depth': 10, 'max_features': 12}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:09,019] Trial 28 finished with value: 51.57192472523986 and parameters: {'n_estimators': 247, 'max_depth': 10, 'max_features': 13}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:09,082] Trial 29 finished with value: 51.244768972644536 and parameters: {'n_estimators': 245, 'max_depth': 10, 'max_features': 7}. Best is trial 1 with value: 50.99801580475954.
# [I 2021-07-16 12:10:09,088] Trial 30 finished with value: 50.647629053924646 and parameters: {'n_estimators': 239, 'max_depth': 10, 'max_features': 8}. Best is trial 30 with value: 50.647629053924646.
# [I 2021-07-16 12:10:09,313] Trial 31 finished with value: 51.71687065547269 and parameters: {'n_estimators': 235, 'max_depth': 10, 'max_features': 8}. Best is trial 30 with value: 50.647629053924646.
# Training Gradient Boosting Model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4242a4976f6f> in <module>
#      15
#      16             #отбор предикторов
# ---> 17             features_to_remove = feature_selector(product_X_train, product_y_train, 0.9)
#      18             product_X_train_fs = remove_features(product_X_train, features_to_remove)
#      19             product_X_test_fs = remove_features(product_X_test, features_to_remove)
#
# <ipython-input-9-466f3c75d052> in feature_selector(x_data, y_data, cumulative_importance, exceptions, from_file, file_path)
#      21             cumulative_importance = fs_cumulative_importance
#      22         fs = FeatureSelector(data=x_data, labels=y_data)
# ---> 23         fs.identify_zero_importance(task='regression',
#      24                                     n_iterations=10,
#      25                                     early_stopping=False)
#
# ~\Anaconda3\lib\site-packages\feature_selector\feature_selector.py in identify_zero_importance(self, task, eval_metric, n_iterations, early_stopping)
#     317
#     318             else:
# --> 319                 model.fit(features, labels)
#     320
#     321             # Record the feature importances
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     816             callbacks=None, init_model=None):
#     817         """Docstring is inherited from the LGBMModel."""
# --> 818         super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     819                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     820                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     681             init_model = init_model.booster_
#     682
# --> 683         self._Booster = train(params, train_set,
#     684                               self.n_estimators, valid_sets=valid_sets, valid_names=eval_names,
#     685                               early_stopping_rounds=early_stopping_rounds,
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     271         booster.best_score[dataset_name][eval_name] = score
#     272     if not keep_training_booster:
# --> 273         booster.model_from_string(booster.model_to_string(), False).free_dataset()
#     274     return booster
#     275
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in model_to_string(self, num_iteration, start_iteration, importance_type)
#    3021             string_buffer = ctypes.create_string_buffer(actual_len)
#    3022             ptr_string_buffer = ctypes.c_char_p(*[ctypes.addressof(string_buffer)])
# -> 3023             _safe_call(_LIB.LGBM_BoosterSaveModelToString(
#    3024                 self.handle,
#    3025                 ctypes.c_int(start_iteration),
#
# KeyboardInterrupt:

# %%
#print(dict_for_model.keys())
dict_for_model, model_control_tab = model_control(dict_to_check=dict_for_model, model_tag='stacking', 
                                                  mark_type = 'pearsonr', mark_value = [0.5,0.05], drop_from_dict=False)
print(model_control_tab)
#print(dict_for_model.keys())

# %%
#print(dict_for_model.keys())
dict_for_model, model_control_tab = model_control(dict_to_check=dict_for_model, model_tag='stacking', 
                                                  mark_type = 'wmape', mark_value = 65, drop_from_dict=False)
print(model_control_tab)
#print(dict_for_model.keys())

# %%
print(dict_for_model.keys())
dict_for_model, model_control_tab = model_control(dict_to_check=dict_for_model, model_tag='stacking', 
                                                  mark_type = 'all', mark_value = [0.5,0.05,65], drop_from_dict=False)
print(model_control_tab)
print(dict_for_model.keys())

# %%
dict_for_model
# Out:
# {'55251': {'s_count_test': 1950       0.0
#   4985      50.0
#   5118      30.0
#   5418       5.0
#   7610      15.0
#             ...
#   256570     0.0
#   258523     5.0
#   260424    30.0
#   265055    10.0
#   265227     5.0
#   Name: s_count, Length: 144, dtype: float64,
#   'price_test': 1950      254.170435
#   4985      245.700000
#   5118      245.700000
#   5418      245.700000
#   7610      245.700000
#                ...
#   256570    254.170435
#   258523    245.700000
#   260424    245.700000
#   265055    245.700000
#   265227    245.700000
#   Name: price, Length: 144, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=7,
#                                                        max_features=17,
#                                                        n_estimators=452,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.3398,
#                                                            max_depth=14,
#                                                            max_features=9,
#                                                            n_estimators=330,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=7,
#                                                           n_estimators=452,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([ 0.        , 27.6182471 , 36.19285836, 22.61537191, 35.78434606,
#          27.11099366,  0.06637168,  0.        ,  0.06637168, 31.17930723,
#           3.85933078,  0.06637168, 25.27802996, 29.2829621 , 26.0885653 ,
#           2.15575873,  1.64823009, 33.4896802 ,  0.        ,  2.22170646,
#           0.        ,  0.        ,  0.06637168, 23.23890775, 21.02610853,
#          25.25312131, 29.0469767 ,  0.17699115,  5.25060893, 27.21574622,
#          29.01060707, 26.09054142, 34.16645497, 29.7042345 , 30.10529464,
#           5.66832834, 35.5722392 ,  1.84734513,  1.6229329 , 23.82584696,
#           0.        , 24.60366884, 24.88393775, 22.49057762, 22.46115561,
#          29.57478701,  0.        ,  0.06637168,  1.77355762, 25.83710333,
#          22.46552214, 28.20993752, 30.06015354,  3.69903793, 23.77864236,
#          28.75302819,  0.06637168, 29.63708716,  1.70718594, 34.95916361,
#           0.06637168,  1.77355762, 30.70146321, 25.22366032,  0.        ,
#          22.63870553, 23.18934386, 25.20940436, 30.42123466, 24.27565968,
#          23.067833  ,  1.70718594, 29.3275199 ,  1.84734513, 30.48708879,
#           0.06637168,  4.09735102, 25.87093166, 23.33707281,  0.06637168,
#          31.67448152,  2.38311822, 24.8043051 , 29.01185692, 20.71835274,
#          29.24565539, 29.93751298, 21.70001686, 23.24446753, 22.22000331,
#           0.51029844, 24.07434581,  2.20423609, 26.67551605, 24.1785744 ,
#          27.86899349, 29.90530984,  3.73821308, 29.68885575, 28.62775602,
#          28.36094717,  4.29916197, 26.81651013, 32.03181725, 25.58550886,
#           1.70718594, 23.18123486, 24.87389576,  0.        , 29.01097882,
#           0.        , 29.48901506, 30.06104555, 29.50301469, 26.99730908,
#          29.49886836, 28.6347723 , 26.51289607, 29.05869883,  4.33750325,
#          31.74642614, 29.7163538 ,  1.77355762,  0.06637168,  0.        ,
#          31.53941623,  1.77355762,  3.88420652, 24.5799107 , 25.77607288,
#           0.        , 30.9695052 , 36.50096229,  2.17207559, 28.11503982,
#          30.35131456, 31.84295003, 22.97730635, 24.52461455,  0.        ,
#          25.67200382, 21.52185394, 21.25114613, 26.83069273]),
#   'wmape_stacking_test': 66.90041978440934,
#   'r_stacking_test': 0.6048378549232525,
#   'p_value_stacking_test': 9.884887885715502e-16,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_max_cprice_l15', 'abs_dev_avg_cprice_l1',
#          'abs_dev_avg_cprice_l14', 'rel_dev_min_cprice_l0',
#          'rel_dev_avg_cprice_l1', 'rel_dev_max_cprice_l1',
#          'rel_dev_avg_cprice_l13', 'month', 'abs_dev_max_cprice_l3',
#          'rel_dev_avg_cprice_l5', 'rel_dev_min_cprice_l14',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_avg_cprice_l15',
#          'abs_dev_min_cprice_l2', 'rel_dev_max_cprice_l3',
#          'abs_dev_avg_cprice_l2', 'abs_dev_avg_cprice_l15',
#          'abs_dev_max_cprice_l13', 'year', 'abs_dev_max_cprice_l7', 'store_id',
#          'day'],
#         dtype='object')},
#  '55252': {'s_count_test': 146        5.0
#   7229       0.0
#   8485      40.0
#   10567      0.0
#   11292     30.0
#             ...
#   249285    50.0
#   252919     0.0
#   253244     0.0
#   263396     0.0
#   263630    10.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 146       245.700000
#   7229      252.954645
#   8485      284.700000
#   10567     252.954645
#   11292     245.700000
#                ...
#   249285    245.700000
#   252919    252.954645
#   253244    252.954645
#   263396    252.954645
#   263630    284.700000
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=2,
#                                                        max_features=16,
#                                                        n_estimators=285,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.7046,
#                                                            max_depth=20,
#                                                            max_features=10,
#                                                            n_estimators=418,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=2,
#                                                           n_estimators=285,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([24.33843148,  0.10306981, 23.03327389,  0.10306981, 24.46747753,
#          24.37167832, 24.30792038,  0.0446872 , 25.27715887, 23.94577743,
#           0.0446872 , 23.37982844, 24.14261529, 25.26307298, 24.09745202,
#          24.45386   , 24.529168  , 22.4666043 , 24.3002373 , 25.29584836,
#          23.71909688, 24.31781707, 21.73663309, 25.21752624,  0.10306981,
#          24.49866126, 25.35465361, 24.15878235, 23.16425805,  0.0446872 ,
#           0.10306981, 25.3249591 ,  0.0446872 , 24.23449049, 24.04709687,
#           0.0446872 , 24.49361289, 24.5006171 , 23.72851377, 24.41568507,
#          25.32253902, 24.36047621, 24.11253537,  0.0446872 ,  0.0446872 ,
#          23.38346587, 23.40361867, 24.54632852, 25.24783048,  0.10306981,
#           0.0446872 , 22.77137496, 25.22901945, 25.19568759, 25.29862018,
#          23.3327322 ,  0.10306981, 22.89119836,  0.0446872 , 23.32592096,
#           0.0446872 , 24.52890789, 24.41083879, 24.52103686, 24.3258374 ,
#           0.10306981, 24.00128182, 24.52731406, 24.4187162 , 24.17269179,
#          25.4753353 ,  0.10306981, 24.09745202,  0.0446872 , 24.35059246,
#          22.80832525,  0.08552595, 24.23998624,  0.08552595, 25.88577935,
#          24.06881037, 22.96194814,  0.10306981, 23.01585326,  0.0446872 ,
#          25.17519636, 24.3200407 ,  0.0446872 , 24.37140736, 25.29818564,
#          23.48223964,  0.0446872 ,  0.0446872 , 23.55832955,  0.0446872 ,
#          25.23402898, 25.17357041,  0.0446872 , 24.15741896, 24.57774052,
#           0.10306981, 23.28238997,  0.0446872 ,  0.0446872 , 25.31515307,
#           0.10306981,  0.0446872 , 24.46319798, 24.4912633 , 24.3757187 ,
#           0.0446872 , 24.21289533, 24.40003378,  0.0446872 , 24.52890789,
#          24.35667242, 24.41963003, 23.93995149,  0.08552595, 23.23575535,
#          23.71732004,  0.10306981,  0.0446872 ,  0.0446872 ,  0.0446872 ,
#          24.51306979, 24.49719278,  0.0446872 , 24.14825733, 24.57407116,
#          25.16028232, 24.95671116,  0.0446872 , 23.07131046, 24.54496514,
#          26.01195914, 24.37805599,  0.08552595,  0.10306981, 25.29910626,
#           0.0446872 , 25.2680753 ,  0.10306981, 10.00277596,  0.10306981,
#          25.79215701]),
#   'wmape_stacking_test': 84.04570715537923,
#   'r_stacking_test': 0.5009962730554047,
#   'p_value_stacking_test': 1.192632256291679e-10,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_avg_cprice_l1', 'rel_dev_min_cprice_l0',
#          'rel_dev_avg_cprice_l1', 'abs_dev_min_cprice_l0',
#          'rel_dev_max_cprice_l1', 'month', 'abs_dev_max_cprice_l3',
#          'rel_dev_avg_cprice_l5', 'abs_dev_avg_cprice_l7',
#          'rel_dev_avg_cprice_l4', 'rel_dev_max_cprice_l3',
#          'abs_dev_avg_cprice_l2', 'year', 'abs_dev_max_cprice_l7', 'store_id',
#          'day'],
#         dtype='object')},
#  '55191': {'s_count_test': 1694       5.0
#   3574       0.0
#   5536       5.0
#   6418      65.0
#   7622      15.0
#             ...
#   256568    10.0
#   258473     0.0
#   261633     0.0
#   264934     0.0
#   265226     0.0
#   Name: s_count, Length: 145, dtype: float64,
#   'price_test': 1694      258.700000
#   3574      253.357303
#   5536      258.700000
#   6418      245.700000
#   7622      258.700000
#                ...
#   256568    258.700000
#   258473    253.357303
#   261633    253.357303
#   264934    253.357303
#   265226    253.357303
#   Name: price, Length: 145, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=3,
#                                                        max_features=11,
#                                                        n_estimators=438,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.2361,
#                                                            max_depth=14,
#                                                            max_features=16,
#                                                            n_estimators=216,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=3,
#                                                           n_estimators=438,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([1.99114016e+01, 1.61254042e-02, 2.32067729e+01, 2.15337238e+01,
#          2.28132844e+01, 2.57788085e+01, 2.24680461e+01, 2.06649298e+01,
#          5.40219944e-01, 1.61254042e-02, 2.14860500e+01, 2.03620198e+01,
#          2.54831816e-01, 2.00960201e+01, 2.29180859e+01, 2.43320709e+01,
#          2.11448388e+01, 2.42258963e+01, 1.41288483e-01, 2.02322318e+01,
#          1.61254042e-02, 2.26605769e+01, 1.41288483e-01, 2.13888098e+01,
#          2.44800005e+01, 1.61254042e-02, 1.61254042e-02, 2.11480512e+01,
#          1.41288483e-01, 5.40219944e-01, 1.41288483e-01, 2.03398901e+01,
#          2.16199224e+01, 2.15758808e+01, 2.18137116e+01, 1.98004531e-01,
#          2.28699479e+01, 1.95430916e+01, 2.00031822e+01, 2.10960235e+01,
#          2.59323458e+01, 5.40219944e-01, 2.28580877e+01, 1.61254042e-02,
#          1.94389793e+01, 2.00016417e+01, 1.95731811e+01, 1.61254042e-02,
#          1.61254042e-02, 1.96030358e+01, 2.41698708e+01, 2.08271215e+01,
#          2.09911401e+01, 1.29872958e-01, 2.06297500e+01, 2.01741023e+01,
#          2.14491150e+01, 1.41288483e-01, 2.51866527e+01, 2.30318785e+01,
#          1.92900776e+01, 2.00340105e+01, 1.41288483e-01, 2.14135893e+01,
#          1.61254042e-02, 2.30040441e+01, 2.00057450e+01, 1.61254042e-02,
#          1.91469838e+01, 1.41288483e-01, 2.23225531e+01, 1.98251789e+01,
#          1.93635441e+01, 2.32778402e+01, 2.02128480e+01, 2.22384495e+01,
#          1.61254042e-02, 1.61254042e-02, 1.61254042e-02, 1.93702733e+01,
#          1.41288483e-01, 2.04312310e+01, 1.98004531e-01, 2.45239349e+01,
#          2.39025631e+01, 2.05654151e+01, 1.61254042e-02, 2.23390964e+01,
#          1.93148595e+01, 1.61254042e-02, 2.02700994e+01, 2.22409882e+01,
#          2.10405650e+01, 1.95032314e+01, 2.61813490e+01, 2.15291604e+01,
#          1.61254042e-02, 2.04498368e+01, 2.18134757e+01, 2.35274822e+01,
#          2.57042856e+01, 2.44208495e+01, 2.11504137e+01, 2.56364320e+01,
#          2.00557015e+01, 1.61254042e-02, 1.96585006e+01, 1.41288483e-01,
#          2.30552446e+01, 2.18723693e+01, 1.61254042e-02, 1.96490677e+01,
#          2.00667935e+01, 1.61254042e-02, 2.30163468e+01, 1.94135413e+01,
#          2.31716098e+01, 1.41288483e-01, 2.27738250e+01, 2.41833030e+01,
#          2.39380849e+01, 2.39462825e+01, 2.44308784e+01, 1.29872958e-01,
#          2.02674179e+01, 1.61254042e-02, 2.26476975e+01, 1.41288483e-01,
#          2.01978486e+01, 1.96730407e+01, 2.58190761e+01, 2.14969711e+01,
#          2.29868090e+01, 2.47193453e+01, 2.14565896e+01, 2.36040146e+01,
#          2.09823711e+01, 2.32227298e+01, 1.61254042e-02, 1.71038285e+01,
#          1.95025760e+01, 1.61254042e-02, 1.61254042e-02, 1.61254042e-02,
#          1.61254042e-02]),
#   'wmape_stacking_test': 68.35815703615899,
#   'r_stacking_test': 0.5505609868141699,
#   'p_value_stacking_test': 7.277535828095413e-13,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_max_cprice_l15', 'abs_dev_avg_cprice_l1',
#          'abs_dev_avg_cprice_l14', 'rel_dev_min_cprice_l0',
#          'rel_dev_avg_cprice_l1', 'abs_dev_min_cprice_l0',
#          'rel_dev_max_cprice_l1', 'rel_dev_avg_cprice_l13', 'month',
#          'abs_dev_max_cprice_l3', 'rel_dev_avg_cprice_l5',
#          'rel_dev_min_cprice_l14', 'abs_dev_avg_cprice_l7',
#          'rel_dev_avg_cprice_l4', 'rel_dev_avg_cprice_l8',
#          'rel_dev_avg_cprice_l15', 'rel_dev_max_cprice_l3',
#          'abs_dev_avg_cprice_l2', 'abs_dev_min_cprice_l14', 'year', 'store_id',
#          'day'],
#         dtype='object')},
#  '55192': {'s_count_test': 2311       5.0
#   3425       5.0
#   4474      30.0
#   5793      10.0
#   6022       0.0
#             ...
#   249286     5.0
#   252520    20.0
#   252598     5.0
#   253382     5.0
#   254191    15.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 2311      258.700000
#   3425      245.700000
#   4474      258.700000
#   5793      245.700000
#   6022      253.293874
#                ...
#   249286    258.700000
#   252520    258.700000
#   252598    245.700000
#   253382    245.700000
#   254191    245.700000
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=3,
#                                                        max_features=15,
#                                                        n_estimators=415,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.3655,
#                                                            max_depth=14,
#                                                            max_features=3,
#                                                            n_estimators=492,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=3,
#                                                           n_estimators=415,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([1.67772715e+01, 1.91486899e+01, 1.85509220e+01, 1.77766433e+01,
#          5.35832280e-03, 1.77564094e+01, 1.87152261e+01, 5.35832280e-03,
#          1.81795872e+01, 1.85522833e+01, 1.80318538e+01, 1.78117300e+01,
#          1.66221681e+01, 1.95653172e+01, 1.95193454e+01, 1.97331182e+01,
#          2.09280310e+01, 5.35832280e-03, 1.68131873e+01, 5.35832280e-03,
#          1.69599446e-01, 1.67691688e+01, 5.35832280e-03, 1.75906064e+01,
#          1.64686536e+01, 1.78328451e+01, 1.70325854e+01, 5.35832280e-03,
#          5.35832280e-03, 1.80189581e+01, 1.69768298e+01, 1.69276823e+01,
#          2.09262801e+01, 1.56991993e+01, 1.82843370e+01, 1.67184953e+01,
#          1.95653172e+01, 1.80413603e+01, 1.80735729e+01, 1.69459375e+01,
#          1.78240628e+01, 1.83564191e+01, 1.82294622e+01, 1.69996380e+01,
#          5.35832280e-03, 1.82259612e+01, 1.69383423e+01, 1.93293224e+01,
#          1.83112339e+01, 1.94997274e+01, 1.87030027e+01, 5.35832280e-03,
#          5.35832280e-03, 1.62004366e+01, 1.78453291e+01, 5.35832280e-03,
#          5.35832280e-03, 5.35832280e-03, 1.84589672e+01, 1.87331600e+01,
#          1.83805105e+01, 1.81646617e+01, 5.35832280e-03, 5.35832280e-03,
#          1.79455322e+01, 1.78705994e+01, 1.84812556e+01, 2.15327215e+01,
#          1.78263912e+01, 1.63852884e+01, 1.80732716e+01, 5.35832280e-03,
#          1.71925829e+01, 1.91969206e+01, 1.69845435e+01, 1.78348499e+01,
#          1.80130842e+01, 5.35832280e-03, 1.31074331e-01, 1.78117300e+01,
#          1.81857390e+01, 1.92021182e+01, 2.09280310e+01, 5.35832280e-03,
#          1.78927486e+01, 1.70534231e+01, 1.64335669e+01, 1.68771174e+01,
#          1.52592963e+01, 1.54539852e+01, 5.35832280e-03, 1.67500355e+01,
#          1.81884626e+01, 5.35832280e-03, 5.35832280e-03, 5.35832280e-03,
#          1.81521513e+01, 1.77343215e+01, 1.67957039e+01, 1.75848682e+01,
#          1.81693609e+01, 1.87709474e+01, 1.84248739e+01, 5.35832280e-03,
#          1.86193783e+01, 5.35832280e-03, 1.58738601e+01, 1.84052529e+01,
#          1.70455641e+01, 1.96302776e+01, 1.87284469e+01, 2.06717003e+01,
#          5.35832280e-03, 1.65818973e+01, 5.35832280e-03, 1.69768298e+01,
#          5.35832280e-03, 5.35832280e-03, 1.84956545e+01, 1.81601151e+01,
#          1.93634348e+01, 5.35832280e-03, 1.67794087e+01, 5.35832280e-03,
#          5.35832280e-03, 1.59914526e+01, 5.35832280e-03, 1.69936600e+01,
#          1.84386297e+01, 1.66352346e+01, 1.63759947e+01, 2.12296439e+01,
#          1.84913022e+01, 1.83561810e+01, 1.66078348e+01, 1.68937101e+01,
#          1.69365721e+01, 5.35832280e-03, 1.78800789e+01, 1.86181604e+01,
#          1.75208936e+01, 1.70268146e+01, 1.88215979e+01, 1.80640544e+01,
#          1.79520019e+01, 1.54147968e+01]),
#   'wmape_stacking_test': 62.87015683442673,
#   'r_stacking_test': 0.523640253484177,
#   'p_value_stacking_test': 1.1865374755462046e-11,
#   'stacking_columns': Index(['rel_dev_min_cprice_l9', 'price', 'abs_dev_avg_cprice_l4',
#          'rel_dev_max_cprice_l5', 'abs_dev_avg_cprice_l1',
#          'rel_dev_avg_cprice_l1', 'rel_dev_max_cprice_l1', 'month',
#          'abs_dev_max_cprice_l3', 'rel_dev_avg_cprice_l5',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_max_cprice_l3',
#          'abs_dev_avg_cprice_l2', 'year', 'abs_dev_max_cprice_l7', 'store_id',
#          'day'],
#         dtype='object')},
#  '54551': {'s_count_test': 733       25.0
#   1810      15.0
#   2888      30.0
#   4255      20.0
#   8488      10.0
#             ...
#   261010    35.0
#   261553     0.0
#   264921    45.0
#   266528    35.0
#   266596    20.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 733       76.411111
#   1810      79.444444
#   2888      76.411111
#   4255      82.188889
#   8488      80.744444
#               ...
#   261010    80.352381
#   261553    80.955304
#   264921    76.411111
#   266528    76.411111
#   266596    76.411111
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=4,
#                                                        max_features=17,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.3564,
#                                                            max_depth=13,
#                                                            max_features=15,
#                                                            n_estimators=186,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=4,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([25.97309637, 25.33820862, 26.00425821, 21.71158905, 22.02896671,
#          21.67870618, 25.90079181, 21.97617563, 27.03851763, 26.43971816,
#          25.91070585, 19.90474158, 22.64224339, 22.82877996, 22.77686524,
#          21.55738178, 24.78512983, 22.89787581, 17.07641277, 23.97200797,
#          25.79328356, 26.35559565, 22.41240079, 17.55821475, 26.255583  ,
#          21.55844729, 21.36019411, 21.22876942, 20.77762661, 24.78524626,
#          21.75223924, 22.25060818, 20.78614479, 22.27522135, 21.53063824,
#          26.18518788, 26.49437821, 21.60258137, 27.05067417, 26.30337278,
#          23.82270868, 24.97685434, 21.25817741, 26.72794202, 26.49006262,
#          25.18083698, 25.72567266, 25.31388692, 25.52765038, 21.45152727,
#          25.40715494, 22.20259004, 21.01845015, 21.45858072, 23.59350268,
#          21.42060065, 21.55912167, 25.18906814,  4.96726197, 23.99218207,
#          21.45152727, 22.32264515, 20.8863764 , 20.99113596, 23.61630032,
#          21.55262036, 23.52360405, 25.75841887, 26.58432616, 24.91326057,
#          17.62550973, 21.43222371, 23.42009849, 21.39985117, 21.03671823,
#          13.21885193, 25.61229457, 19.40889065, 26.3636604 , 26.30302784,
#          21.26619354, 21.49283895, 21.04169698, 21.90970789, 21.6716192 ,
#          21.39201654, 25.43091257, 26.34794226, 25.34343229, 10.91469472,
#          20.87247021, 21.2647468 , 25.51733753, 21.4253057 , 24.6758027 ,
#          24.90669872, 21.0627273 , 25.91344044, 22.42785164, 22.16473   ,
#          21.40644237, 21.46924923, 26.41113568, 22.31742838, 26.12898531,
#          21.72042412, 23.12286661, 20.23500004, 23.88389218, 24.23024746,
#          25.62564   , 19.41578912, 25.3678404 , 26.63698523, 23.01574299,
#          25.89076374, 19.13766602, 22.54120176, 22.54749873, 26.87224694,
#          24.99685583, 25.13754489, 25.12480714, 21.64290375, 21.63555462,
#          21.234035  , 25.30885065, 21.06415492, 17.80272683, 21.31535151,
#          21.74272521, 20.5862821 , 26.29167   , 25.9020099 , 21.80907077,
#          22.57484939, 21.39569227, 18.64444607, 26.2100809 , 15.6579945 ,
#          23.15315156, 24.90684076, 20.74506041, 26.5744528 , 25.78894843,
#          17.71264281]),
#   'wmape_stacking_test': 56.95815811173342,
#   'r_stacking_test': 0.15483531565880015,
#   'p_value_stacking_test': 0.062031443788581844,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_avg_cprice_l1', 'rel_dev_avg_cprice_l1',
#          'rel_dev_max_cprice_l1', 'abs_dev_min_cprice_l6', 'month',
#          'abs_dev_max_cprice_l3', 'rel_dev_avg_cprice_l5',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_max_cprice_l3',
#          'abs_dev_avg_cprice_l2', 'rel_dev_avg_cprice_l2',
#          'abs_dev_max_cprice_l5', 'abs_dev_avg_cprice_l5', 'year',
#          'abs_dev_max_cprice_l7', 'store_id', 'abs_dev_avg_cprice_l6', 'day',
#          'abs_dev_avg_cprice_l9', 'rel_dev_avg_cprice_l9'],
#         dtype='object')},
#  '54552': {'s_count_test': 4245      10.0
#   7621      10.0
#   8382       5.0
#   8413       0.0
#   9914       5.0
#             ...
#   248321     5.0
#   248438    15.0
#   248447    10.0
#   249933     0.0
#   258260     5.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 4245      76.411111
#   7621      82.188889
#   8382      76.411111
#   8413      85.163356
#   9914      76.411111
#               ...
#   248321    76.411111
#   248438    76.411111
#   248447    76.411111
#   249933    85.163356
#   258260    82.188889
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=10,
#                                                        max_features=3,
#                                                        n_estimators=429,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=1.167,
#                                                            max_depth=20,
#                                                            max_features=27,
#                                                            n_estimators=330,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=10,
#                                                           n_estimators=429,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([1.20278820e+01, 6.79331938e+00, 1.25551480e+01, 0.00000000e+00,
#          1.06171307e+01, 8.46033915e+00, 7.81159936e+00, 7.33741363e+00,
#          0.00000000e+00, 1.06628283e+01, 7.93402729e+00, 1.44206392e+01,
#          7.67255263e+00, 1.05839023e+01, 8.27855297e+00, 0.00000000e+00,
#          8.15500558e+00, 0.00000000e+00, 1.07945570e+01, 1.19349162e+01,
#          9.66117142e+00, 6.82950573e+00, 0.00000000e+00, 1.35917365e+01,
#          6.58102053e+00, 0.00000000e+00, 0.00000000e+00, 3.49650350e-02,
#          9.77121953e+00, 8.89331101e+00, 0.00000000e+00, 0.00000000e+00,
#          7.78244446e+00, 1.23618932e+01, 9.48483714e+00, 6.30144282e+00,
#          0.00000000e+00, 1.10710634e+01, 1.04314978e+01, 8.86056421e+00,
#          7.56655393e-01, 0.00000000e+00, 0.00000000e+00, 5.10260996e+00,
#          1.09110870e+01, 1.19466281e+01, 1.28690354e+01, 1.07054590e+01,
#          6.41942813e+00, 6.89673178e+00, 0.00000000e+00, 1.14274810e+01,
#          0.00000000e+00, 8.05318383e+00, 0.00000000e+00, 4.94177761e+00,
#          0.00000000e+00, 0.00000000e+00, 1.13444000e+01, 1.04688530e+01,
#          7.87913475e+00, 0.00000000e+00, 8.27674010e+00, 9.28814018e+00,
#          0.00000000e+00, 3.49650350e-02, 3.49650350e-02, 7.19709119e+00,
#          1.16550117e-02, 8.20024770e+00, 1.76929825e+01, 9.38123834e+00,
#          1.16550117e-02, 1.09622381e+01, 8.16440070e+00, 0.00000000e+00,
#          8.31063362e-01, 6.59765722e+00, 1.03253438e+01, 9.50734160e+00,
#          1.03266836e+01, 1.09368014e+01, 1.27589015e+01, 7.18053090e+00,
#          7.90239736e+00, 0.00000000e+00, 1.00395396e+01, 0.00000000e+00,
#          1.04910791e+01, 1.24424263e+01, 0.00000000e+00, 3.49650350e-02,
#          9.25777509e+00, 9.13689958e+00, 8.01206562e+00, 8.31093648e+00,
#          0.00000000e+00, 1.37071712e+01, 0.00000000e+00, 5.44089803e+00,
#          9.90966070e+00, 0.00000000e+00, 1.08170892e+01, 7.31654088e+00,
#          8.82506982e+00, 1.10540113e+01, 9.06881824e+00, 8.17325279e+00,
#          0.00000000e+00, 0.00000000e+00, 1.07805612e+01, 9.02240364e+00,
#          0.00000000e+00, 0.00000000e+00, 3.49650350e-02, 6.14314801e+00,
#          3.49650350e-02, 0.00000000e+00, 6.49060079e+00, 0.00000000e+00,
#          0.00000000e+00, 0.00000000e+00, 1.07931410e+01, 1.08196579e+01,
#          2.33100233e-02, 8.81393775e+00, 3.49650350e-02, 0.00000000e+00,
#          9.29145627e+00, 0.00000000e+00, 1.03647417e+01, 9.38570913e+00,
#          9.22666809e+00, 0.00000000e+00, 9.16329795e+00, 9.45216530e+00,
#          7.17816771e+00, 0.00000000e+00, 1.09195383e+01, 1.04334877e+01,
#          1.08013174e+01, 1.17676527e+01, 1.28694990e+01, 1.07453174e+01,
#          0.00000000e+00, 7.82736704e+00]),
#   'wmape_stacking_test': 45.785204017031376,
#   'r_stacking_test': 0.7513628094188294,
#   'p_value_stacking_test': 8.866028881821267e-28,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_max_cprice_l15', 'abs_dev_avg_cprice_l1',
#          'abs_dev_avg_cprice_l14', 'rel_dev_avg_cprice_l1',
#          'abs_dev_max_cprice_l6', 'rel_dev_max_cprice_l1',
#          'abs_dev_min_cprice_l6', 'rel_dev_avg_cprice_l13', 'month',
#          'abs_dev_max_cprice_l3', 'rel_dev_avg_cprice_l5',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_avg_cprice_l15',
#          'rel_dev_max_cprice_l3', 'abs_dev_avg_cprice_l2',
#          'abs_dev_avg_cprice_l15', 'rel_dev_avg_cprice_l2',
#          'abs_dev_avg_cprice_l5', 'year', 'abs_dev_max_cprice_l7', 'store_id',
#          'abs_dev_avg_cprice_l6', 'day', 'abs_dev_avg_cprice_l9',
#          'rel_dev_avg_cprice_l9'],
#         dtype='object')},
#  '54591': {'s_count_test': 7209       5.0
#   8091      10.0
#   8133       0.0
#   9070       5.0
#   11009     15.0
#             ...
#   259359     5.0
#   260230    10.0
#   260844     5.0
#   266101     5.0
#   267162     5.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 7209      101.483871
#   8091      112.317204
#   8133      103.293377
#   9070      101.483871
#   11009     104.698925
#                ...
#   259359    103.440860
#   260230    103.440860
#   260844    103.440860
#   266101    103.440860
#   267162    103.440860
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=10,
#                                                        max_features=25,
#                                                        n_estimators=233,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.219,
#                                                            max_depth=6,
#                                                            max_features=13,
#                                                            n_estimators=177,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=10,
#                                                           n_estimators=233,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([11.72371407,  8.28685441,  0.25751073,  8.97162705,  8.20742225,
#           0.19313305,  8.15656753,  0.        , 10.86786408,  0.        ,
#           7.91731919,  7.98278189,  0.        ,  0.        ,  7.81415086,
#           8.36951377,  9.10784428,  9.95654773,  7.593842  , 11.30991765,
#           7.77690325,  0.        ,  7.25156791,  0.06437768,  0.        ,
#           0.19313305,  0.        , 10.66197254,  0.        ,  0.        ,
#           0.19313305,  0.        ,  9.08584125,  8.00240301,  9.45240584,
#           0.        ,  0.        ,  7.65676916, 14.06026817,  4.45098843,
#           8.18377217,  7.79725825,  8.02174766,  0.19313305,  0.        ,
#           8.79609327,  9.95479572,  4.24347708,  7.86019604,  0.21459227,
#           7.65223337,  9.4680623 ,  9.05543382,  9.42495909,  0.        ,
#           7.76091217,  0.21459227,  0.21459227,  9.81409957,  7.882435  ,
#           7.86376545,  0.12875536,  0.        ,  0.06437768,  0.61373391,
#           8.4278483 ,  7.73538726,  0.15021459,  0.19313305,  0.        ,
#           0.15021459,  0.        ,  7.9183911 ,  0.04291845,  0.        ,
#           8.01891764,  0.        ,  7.89385676,  0.        ,  0.15021459,
#          12.10087464,  4.27222619,  0.2360515 ,  8.36247889,  0.19313305,
#           0.        ,  8.14022338,  8.01010255,  0.        ,  7.02045996,
#           8.81825954, 11.12797301,  0.15021459,  8.24598063,  0.21459227,
#           8.10398113,  7.91243   ,  0.15021459,  8.0161892 ,  8.29401818,
#           8.88142331, 11.1037264 ,  9.61080694,  7.73951379,  9.15989993,
#           0.15021459,  0.25751073,  0.2360515 ,  0.12875536,  8.25251793,
#          10.88037909,  9.39296681, 12.54595055,  8.17520843,  4.40806998,
#           0.        , 10.95909107,  0.        ,  8.17925213,  0.21459227,
#          12.50605885,  0.15021459,  9.20661239,  0.        , 11.69351502,
#           0.        ,  9.14887774, 10.51347822,  7.77088047,  0.        ,
#           7.96243191, 11.86930449,  8.2164547 ,  8.09598361,  0.19313305,
#           0.2360515 ,  0.25751073,  0.        ,  0.12875536,  0.        ,
#           0.25751073,  0.19313305,  0.        ,  0.        ,  0.17167382,
#           0.21459227]),
#   'wmape_stacking_test': 64.1792893733228,
#   'r_stacking_test': 0.3645555475487712,
#   'p_value_stacking_test': 6.075284940635383e-06,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'abs_dev_avg_cprice_l1',
#          'abs_dev_avg_cprice_l14', 'rel_dev_avg_cprice_l1',
#          'rel_dev_max_cprice_l1', 'abs_dev_min_cprice_l6',
#          'rel_dev_avg_cprice_l13', 'month', 'abs_dev_max_cprice_l3',
#          'rel_dev_max_cprice_l13', 'rel_dev_avg_cprice_l5',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_avg_cprice_l15',
#          'rel_dev_max_cprice_l3', 'abs_dev_avg_cprice_l2',
#          'abs_dev_avg_cprice_l15', 'abs_dev_avg_cprice_l5', 'year',
#          'abs_dev_max_cprice_l7', 'store_id', 'abs_dev_avg_cprice_l6',
#          'rel_dev_avg_cprice_l6', 'day', 'rel_dev_min_cprice_l6',
#          'abs_dev_avg_cprice_l9'],
#         dtype='object')},
#  '54592': {'s_count_test': 5         5.0
#   61        0.0
#   672       0.0
#   701       0.0
#   866       5.0
#            ...
#   256326    0.0
#   256497    0.0
#   260958    5.0
#   261208    0.0
#   266458    0.0
#   Name: s_count, Length: 145, dtype: float64,
#   'price_test': 5         103.440860
#   61        102.493934
#   672       102.493934
#   701       102.493934
#   866       103.440860
#                ...
#   256326    102.493934
#   256497    102.493934
#   260958    103.440860
#   261208    102.493934
#   266458    102.493934
#   Name: price, Length: 145, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=8,
#                                                        max_features=22,
#                                                        n_estimators=392,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.598,
#                                                            max_depth=16,
#                                                            max_features=9,
#                                                            n_estimators=191,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=8,
#                                                           n_estimators=392,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([ 6.51581572,  0.        ,  0.        ,  0.        ,  6.86167532,
#           7.02376623,  0.        ,  0.        ,  7.54153532,  0.        ,
#           0.        ,  6.85090758,  6.03750342,  7.90189514,  0.        ,
#           6.22142236,  0.        ,  0.        ,  0.        ,  6.25960789,
#           0.        ,  0.        ,  5.82483147,  0.        ,  6.84528631,
#           0.        ,  0.        ,  0.        ,  5.33885937,  6.46904695,
#           0.        ,  5.22152513,  6.36256431,  8.44469847, 11.71693605,
#           8.13030799,  6.37236807,  0.        , 11.79012217, 11.59877425,
#           0.        ,  0.        ,  5.81156501,  5.85037382,  7.08940503,
#           0.        ,  5.14840997,  0.        ,  0.        ,  5.5516184 ,
#           0.        ,  0.        ,  7.25289238,  6.42391616,  6.30473166,
#           0.        ,  0.        ,  5.32582662,  0.        ,  6.3274756 ,
#           0.        ,  0.        ,  5.24561292,  0.10503725,  0.        ,
#           9.83930851,  5.33277921,  5.27757893,  0.        ,  5.30575819,
#           0.        ,  0.        ,  6.39124712,  0.        ,  8.28603231,
#           5.40358677,  0.        ,  0.        ,  0.11651684,  0.        ,
#           0.        ,  0.        ,  0.        ,  7.3730539 ,  0.        ,
#           6.26986485,  0.        ,  0.        ,  0.        ,  5.24949043,
#           0.        ,  5.14117565,  0.        ,  0.        ,  6.44523571,
#           0.        ,  6.86272793,  6.33070975,  6.91811476,  0.        ,
#           6.11326972,  8.61478373,  9.84493295,  0.        ,  0.        ,
#           6.34006227,  7.37416527,  0.        ,  0.        ,  8.48361822,
#           0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#           6.3969044 ,  6.28574223,  5.18040768,  0.        ,  5.83245915,
#           0.        ,  6.23725756,  0.        ,  5.81375887,  0.        ,
#           6.60596113,  0.        ,  0.        ,  6.45502589,  5.95913868,
#           6.16594229,  7.0704329 ,  6.10247271,  0.        ,  0.        ,
#          11.5394938 ,  6.60692089,  6.46851684,  0.        ,  0.        ,
#           0.        ,  0.        ,  6.40843355,  0.        ,  0.        ]),
#   'wmape_stacking_test': 36.03583398972383,
#   'r_stacking_test': 0.8556978558579784,
#   'p_value_stacking_test': 9.470595566884247e-43,
#   'stacking_columns': Index(['rel_dev_min_cprice_l9', 'price', 'abs_dev_avg_cprice_l4',
#          'abs_dev_avg_cprice_l1', 'abs_dev_avg_cprice_l14',
#          'rel_dev_avg_cprice_l1', 'rel_dev_max_cprice_l1',
#          'abs_dev_min_cprice_l6', 'rel_dev_avg_cprice_l13', 'month',
#          'abs_dev_max_cprice_l3', 'rel_dev_max_cprice_l13',
#          'rel_dev_avg_cprice_l5', 'rel_dev_min_cprice_l14',
#          'abs_dev_avg_cprice_l7', 'rel_dev_avg_cprice_l4',
#          'rel_dev_avg_cprice_l8', 'rel_dev_avg_cprice_l15',
#          'rel_dev_max_cprice_l3', 'abs_dev_avg_cprice_l2',
#          'abs_dev_avg_cprice_l15', 'rel_dev_avg_cprice_l2',
#          'abs_dev_avg_cprice_l5', 'year', 'store_id', 'abs_dev_avg_cprice_l6',
#          'rel_dev_avg_cprice_l6', 'day', 'rel_dev_min_cprice_l6',
#          'abs_dev_avg_cprice_l9', 'rel_dev_avg_cprice_l9'],
#         dtype='object')},
#  '95541': {'s_count_test': 3176       0.0
#   4934       5.0
#   6466       0.0
#   7089      10.0
#   9560      25.0
#             ...
#   260683    10.0
#   261162    10.0
#   264516     0.0
#   264657    25.0
#   264945    25.0
#   Name: s_count, Length: 146, dtype: float64,
#   'price_test': 3176      255.903900
#   4934      296.771429
#   6466      255.903900
#   7089      270.771429
#   9560      248.485714
#                ...
#   260683    296.771429
#   261162    296.771429
#   264516    255.903900
#   264657    296.771429
#   264945    296.771429
#   Name: price, Length: 146, dtype: float64,
#   'stacking': StackingRegressor(estimators=[('model1',
#                                  RandomForestRegressor(max_depth=10,
#                                                        max_features=8,
#                                                        n_estimators=239,
#                                                        random_state=0)),
#                                 ('model2',
#                                  GradientBoostingRegressor(learning_rate=0.06744,
#                                                            max_depth=8,
#                                                            max_features=6,
#                                                            n_estimators=489,
#                                                            random_state=0))],
#                     final_estimator=RandomForestRegressor(max_depth=10,
#                                                           n_estimators=239,
#                                                           random_state=0),
#                     n_jobs=-1, passthrough=True),
#   'stacking_y_predict': array([ 0.        , 12.55964457,  0.041841  , 11.17216294, 10.53573097,
#          11.6836011 ,  9.71925613,  0.08368201, 12.32440372, 11.85822667,
#          11.31648593, 11.68115421,  9.78150466,  9.74515122, 11.25146887,
#          11.96559082, 11.62421764, 11.11583168, 11.71841898, 11.00124622,
#          13.20591626, 11.26873195, 11.40431935,  0.08368201, 13.40476007,
#           9.8167924 , 10.86616196,  0.        , 12.07804246, 11.07014359,
#          11.82755165, 12.08784049,  0.041841  , 13.20231529, 11.16117683,
#          11.60542592, 10.97677465, 11.5384539 , 10.76893971,  0.041841  ,
#          12.86428064,  0.041841  ,  0.        , 13.53479453, 11.51625922,
#          11.62160221, 11.50834367, 11.06575746, 12.05227496, 11.18710344,
#          10.66347225, 10.13729519, 11.66294428, 11.599448  , 11.72110705,
#          10.83152674, 10.85613611, 13.91899253,  9.86598472,  0.        ,
#          11.04592044,  0.041841  , 10.40496654, 10.68123194, 12.68141392,
#          12.03431974,  0.041841  , 10.00314596, 11.50772938, 11.30529143,
#          11.42136554,  9.97863861, 11.23547621, 11.49980562, 11.42268059,
#          10.41395505, 10.35994509, 10.25207698,  9.77891726, 11.00277779,
#          12.30623382, 11.76311204, 10.93877009, 11.71029973, 12.02152673,
#          10.45599375, 11.48947732, 11.9182932 , 11.62515611, 12.92171578,
#          11.26275672, 11.21217791,  0.        ,  0.041841  , 11.49606246,
#           0.041841  , 10.93536079, 12.28822968,  0.041841  , 10.08815095,
#          10.59989984, 11.67064887,  0.        , 11.95719811, 11.39077156,
#           0.12552301, 13.22881053, 11.68503861, 11.61602662, 10.48813335,
#          12.04828694, 10.85244724,  9.867279  ,  0.041841  ,  0.        ,
#          11.87561532, 10.75428941,  0.041841  , 10.93560209, 11.04438197,
#          11.24105913, 10.91622255, 11.43916266, 12.20725886, 10.60145672,
#          10.6482271 ,  0.        , 13.23598877, 11.07144384, 10.52120754,
#          12.00397528, 12.01791363, 11.61244102,  0.10460251, 12.30987301,
#           0.12552301, 11.26664721, 10.7669238 ,  9.09355219,  0.041841  ,
#          11.03566125, 12.30961539, 10.96209305,  0.        , 12.07788311,
#          10.37301111]),
#   'wmape_stacking_test': 44.82369021569326,
#   'r_stacking_test': 0.5739831292500974,
#   'p_value_stacking_test': 3.630622402256386e-14,
#   'stacking_columns': Index(['price', 'abs_dev_avg_cprice_l4', 'rel_dev_max_cprice_l5',
#          'abs_dev_avg_cprice_l1', 'rel_dev_min_cprice_l0',
#          'rel_dev_avg_cprice_l1', 'abs_dev_max_cprice_l6',
#          'abs_dev_min_cprice_l0', 'rel_dev_max_cprice_l1',
#          'abs_dev_min_cprice_l6', 'month', 'abs_dev_max_cprice_l3',
#          'rel_dev_avg_cprice_l5', 'abs_dev_avg_cprice_l7',
#          'rel_dev_avg_cprice_l4', 'rel_dev_avg_cprice_l8',
#          'abs_dev_avg_cprice_l2', 'rel_dev_avg_cprice_l2',
#          'rel_dev_min_cprice_l3', 'year', 'abs_dev_max_cprice_l7', 'store_id',
#          'abs_dev_avg_cprice_l6', 'rel_dev_avg_cprice_l6', 'day',
#          'abs_dev_min_cprice_l3', 'abs_dev_avg_cprice_l9',
#          'rel_dev_avg_cprice_l9'],
#         dtype='object')}}

# %%
correlations_draw(dict_for_model,[],'stacking')

# %%
# Сделать функцию по сохранению словаря в pickle?
dict_name = 'all_models'
pathname = str("C://Users//elena.khotlyannik//Documents//AA//products_models//") 
filename = str(pathname+dict_name+'.csv') 
pickle.dump(dict_for_model, open(filename, 'wb'))

# %% [markdown]
# # NLOpt

# %%
# Сделать функцию по загрузке словаря из pickle?
#загружаю словарь с моделями
dict_name = 'all_models'
pathname = str("C://Users//elena.khotlyannik//Documents//AA//products_models//") 
filename = str(pathname+dict_name+'.csv') 
dict_for_model = pickle.load(open(filename, 'rb'))

# %%
#генерю датасет для оптимизации на одну дату
pc_to_optimize = pc_prepared_test[pc_prepared_test['s_date']=='2018-02-22']

# %%
#убираю из датасета записи, по которым нет модели в словаре
def create_str(x):
    return str(x[0]) + str(x[1])

def drop_unmodeled_from_dt(dt,dict_for_model):
    dt['product_store'] = list(map(create_str, dt[['product_id','store_id']].values))
    dt['isindictionary'] = dt[['product_store']].isin(dict_for_model.keys())
    dt = dt[dt['isindictionary'] == True].drop(['product_store','isindictionary'],axis=1)
    return dt
    
pc_to_optimize = drop_unmodeled_from_dt(pc_to_optimize, dict_for_model)
# Out:
# <ipython-input-25-ee33b7cc0fd5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['product_store'] = list(map(create_str, dt[['product_id','store_id']].values))
# <ipython-input-25-ee33b7cc0fd5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['isindictionary'] = dt[['product_store']].isin(dict_for_model.keys())

# %%
dict_for_model.keys()
pc_to_optimize
# Out:
#            s_date  product_id  s_count group_level0 group_level1 group_level2  \
# 33320  2018-02-22        5455      5.0          0_1          1_1          2_5
# 66748  2018-02-22        5519     20.0          0_1          1_1          2_6
# 100996 2018-02-22        5459      0.0          0_1          1_1          2_5
# 105029 2018-02-22        5525     20.0          0_1          1_1          2_6
# 196035 2018-02-22        5459      5.0          0_1          1_1          2_5
# 216690 2018-02-22        5519     10.0          0_1          1_1          2_6
# 230327 2018-02-22        5455     10.0          0_1          1_1          2_5
# 232362 2018-02-22        9554     20.0          0_1          1_1         2_11
# 244243 2018-02-22        5525     10.0          0_1          1_1          2_6
#
#        group_level3 group_level4 group_level5 group_level6  ...  \
# 33320     3_1_1(s2)    4_8_1(s2)  5_179_1(s2)     6_179_16  ...
# 66748     3_1_1(s2)    4_8_1(s2)  5_181_1(s2)     6_181_20  ...
# 100996    3_1_1(s2)    4_8_1(s2)  5_179_1(s2)     6_179_20  ...
# 105029    3_1_1(s2)    4_8_1(s2)  5_181_1(s2)     6_181_20  ...
# 196035    3_1_1(s1)    4_8_1(s1)  5_179_1(s1)     6_179_20  ...
# 216690    3_1_1(s1)    4_8_1(s1)  5_181_1(s1)     6_181_20  ...
# 230327    3_1_1(s1)    4_8_1(s1)  5_179_1(s1)     6_179_16  ...
# 232362    3_1_2(s1)    4_8_2(s1)  5_189_1(s1)     6_189_32  ...
# 244243    3_1_1(s1)    4_8_1(s1)  5_181_1(s1)     6_181_20  ...
#
#        product_category=СЛИВКИ product_category=СМЕТАНА  \
# 33320                      0.0                      0.0
# 66748                      0.0                      0.0
# 100996                     0.0                      0.0
# 105029                     0.0                      0.0
# 196035                     0.0                      0.0
# 216690                     0.0                      0.0
# 230327                     0.0                      0.0
# 232362                     1.0                      0.0
# 244243                     0.0                      0.0
#
#        product_category=СНЕЖОК product_category=СЫР %  \
# 33320                      0.0                    0.0
# 66748                      0.0                    0.0
# 100996                     0.0                    0.0
# 105029                     0.0                    0.0
# 196035                     0.0                    0.0
# 216690                     0.0                    0.0
# 230327                     0.0                    0.0
# 232362                     0.0                    0.0
# 244243                     0.0                    0.0
#
#        product_category=СЫРОК ТВОРОЖНЫЙ product_category=ТВОРОГ  \
# 33320                               0.0                     0.0
# 66748                               0.0                     0.0
# 100996                              0.0                     0.0
# 105029                              0.0                     0.0
# 196035                              0.0                     0.0
# 216690                              0.0                     0.0
# 230327                              0.0                     0.0
# 232362                              0.0                     0.0
# 244243                              0.0                     0.0
#
#        product_category=ТВОРОЖНЫЙ ПРОДУКТ product_category=ШОКОЛАД  \
# 33320                                 0.0                      0.0
# 66748                                 0.0                      0.0
# 100996                                0.0                      0.0
# 105029                                0.0                      0.0
# 196035                                0.0                      0.0
# 216690                                0.0                      0.0
# 230327                                0.0                      0.0
# 232362                                0.0                      0.0
# 244243                                0.0                      0.0
#
#        product_subtype=МОЛОЧНЫЕ ПРОДУКТЫ  product_type=ПРОДУКТЫ
# 33320                                1.0                    1.0
# 66748                                1.0                    1.0
# 100996                               1.0                    1.0
# 105029                               1.0                    1.0
# 196035                               1.0                    1.0
# 216690                               1.0                    1.0
# 230327                               1.0                    1.0
# 232362                               1.0                    1.0
# 244243                               1.0                    1.0
#
# [9 rows x 140 columns]

# %%
#функция для предсказания значений продаж s_count для оптимизируемого датасета (по каждому product_id+store_id считается по своей модели) 
def predict_calculation(predict_dt, dict_for_model, model_tag = 'stacking' ):
    for product in predict_dt['product_id'].unique():
        for store in predict_dt['store_id'].unique():            
            if (str(product)+str(store)) in dict_for_model.keys() and model_tag in dict_for_model[str(product)+str(store)].keys():
                model = dict_for_model[str(product)+str(store)][model_tag]
                dt_columns = dict_for_model[str(product)+str(store)][model_tag+'_columns']
             #  print(model)
             #  print(product,store,model_name,model,dt_columns)
                product_store_dt = predict_dt[dt_columns][(predict_dt['product_id']==product) & (predict_dt['store_id']==store)]
                predict_dt2 = model.predict(product_store_dt)
                predict_dt.loc[((predict_dt['product_id']==product)& (predict_dt['store_id']==store) ),'s_count'] = predict_dt2
            #y_predict[product_id == product]
    return predict_dt

# %%
#функция для пересчета предикторов (ценового контекста), при подстановке новой цены price_new
def change_context(price_new,dt=pc_to_optimize):
    new_pc = dt.copy()
    new_pc['price'] = price_new
    also_columns = ['store_id','price'] #,'year','month','day']
    table_to_groupby = new_pc[special_cols+also_columns+groupl_cols]
    for level in groupl_cols:    

        new_pc = new_pc.drop(['mean', 'max', 'min'], axis=1, errors = 'ignore')
        agg_prices_table =  table_to_groupby.groupby(['store_id',level])['price'].agg(['mean', 'max', 'min'])
        new_pc = new_pc.join(agg_prices_table, on=['store_id',level], sort=False )
        
        cols_level = [col for col in dt.columns if '_cprice_l'+ str(level)[11:] in col]
        for cols in cols_level:
            if 'max' in cols:
                if  'rel_dev' in cols:
                    new_pc[cols] = (new_pc['price'] - new_pc['max']) /  new_pc['price']
                elif 'abs_dev' in cols:
                    new_pc[cols] = new_pc['price'] - new_pc['max']
            elif 'min' in cols:
                if  'rel_dev' in cols:
                    new_pc[cols] = (new_pc['price'] - new_pc['min']) /  new_pc['price']
                elif 'abs_dev' in cols:
                    new_pc[cols] = new_pc['price'] - new_pc['min']
            elif 'avg' in cols:
                if  'rel_dev' in cols:
                    new_pc[cols] = (new_pc['price'] - new_pc['mean']) /  new_pc['price']
                elif 'abs_dev' in cols:
                    new_pc[cols] = new_pc['price'] - new_pc['mean']
    return new_pc.drop(['mean', 'max', 'min'], axis=1).fillna(0)

# %%
#ограничение на минимальный план по каждому 'product_id'+'store_id'. Проверяем сумму amount
min_plan_dt = pc_to_optimize
def vector_min_plan_constrain(result_min,X, grad = None):
    global min_plan_step
    global min_plan_dt
    global dict_for_model
    
    min_plan_dt=change_context(X,min_plan_dt)
    min_plan_dt['amount'] = X*predict_calculation(min_plan_dt, dict_for_model)['s_count']
    
    result_tab_sum=min_plan_dt.set_index(['product_id','store_id']).join(target_plan.set_index(['product_id','store_id']),  sort=False)
    result_tab_sum['diff'] =  result_tab_sum['min_plan'] - result_tab_sum['amount']
    print('min_plan_step',min_plan_step)
    print(result_tab_sum[['price', 's_count', 'amount','min_plan', 'diff']].head())
    min_plan_constrain = result_tab_sum.values
    min_plan_step = min_plan_step + 1
    result_min[:]=min_plan_constrain[:,-1]

# %%
#ограничение на максимальный план по каждому 'product_id'+'store_id' . Проверяем сумму amount
max_plan_dt = pc_to_optimize
def vector_max_plan_constrain(result_max, X, grad = None):
    global max_plan_step
    global max_plan_dt
    global dict_for_model
    
    max_plan_dt=change_context(X,max_plan_dt)
    max_plan_dt['amount'] = X*predict_calculation(max_plan_dt, dict_for_model)['s_count']
    
    result_tab_sum=max_plan_dt.set_index(['product_id','store_id']).join(target_plan.set_index(['product_id','store_id']), sort=False)
    result_tab_sum['diff'] =  result_tab_sum['amount'] - result_tab_sum['max_plan']    
    print('max_plan_step',max_plan_step)
    print(result_tab_sum[['price', 's_count', 'amount','max_plan', 'diff']].head())
    max_plan_constrain =  result_tab_sum.values
    max_plan_step = max_plan_step + 1
    result_max[:] = max_plan_constrain[:,-1]

# %%
#собственно блок оптимизации
i=1
min_plan_step = 1
max_plan_step = 1

myfunc_dataset = pc_to_optimize.copy()

def myfunc(X, grad = None):  # X = это PRICE 
    global i
    global ff
    global myfunc_dataset
    global dict_for_model
    
    myfunc_dataset=change_context(X,myfunc_dataset)
    sumres = sum(X*predict_calculation(myfunc_dataset, dict_for_model)['s_count'])
    #print(X)
    #print(i, X,round(sumres))
    i = i+1
    return sumres

opt = nlopt.opt(nlopt.LN_AUGLAG, len(myfunc_dataset))
#nlopt.set_local_optimizer
opt.set_max_objective(myfunc)

lower_bounds = pc_to_optimize['price']*0.8 
upper_bounds = pc_to_optimize['price']*1.2 
opt.set_xtol_abs(1)
opt.set_ftol_abs(1000)
opt.set_lower_bounds(lower_bounds)
opt.set_upper_bounds(upper_bounds)

opt.add_inequality_mconstraint(vector_min_plan_constrain, [1]* len(myfunc_dataset))
opt.add_inequality_mconstraint(vector_max_plan_constrain, [1]* len(myfunc_dataset))


#opt.set_xtol_rel(1e-1)
#opt.set_ftol_rel(1e-1)

opt.set_maxeval(500)

X = opt.optimize(pc_to_optimize['price'])
maxf = opt.last_optimum_value()


print("optimum at ",  X)
print("maximum value = ", maxf)
print("result code = ", opt.last_optimize_result())
# Out:
# min_plan_step 1
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          82.188889  18.161561  1492.678548  628.618000
# 5519       2         245.700000  26.886166  6605.931100  385.028024
# 5459       2         102.493934   3.693181   378.528608  586.981538
# 5525       2         284.700000  26.247275  7472.599190  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -864.060548
# 5519       2        -6220.903076
# 5459       2          208.452931
# 5525       2        -7006.838860
# 5459       1         -253.566795
# max_plan_step 1
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          82.188889  18.161561  1492.678548   942.927000
# 5519       2         245.700000  26.886166  6605.931100   577.542035
# 5459       2         102.493934   3.693181   378.528608   880.472308
# 5525       2         284.700000  26.247275  7472.599190   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          549.751548
# 5519       2         6028.389065
# 5459       2         -501.943700
# 5525       2         6773.958696
# 5459       1          -91.388626
# min_plan_step 2
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          82.188889  18.161561  1492.678548  628.618000
# 5519       2         245.700000  26.886166  6605.931100  385.028024
# 5459       2         102.493934   3.693181   378.528608  586.981538
# 5525       2         284.700000  26.247275  7472.599190  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -864.060548
# 5519       2        -6220.903076
# 5459       2          208.452931
# 5525       2        -7006.838860
# 5459       1         -253.566795
# max_plan_step 2
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          82.188889  18.161561  1492.678548   942.927000
# 5519       2         245.700000  26.886166  6605.931100   577.542035
# 5459       2         102.493934   3.693181   378.528608   880.472308
# 5525       2         284.700000  26.247275  7472.599190   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          549.751548
# 5519       2         6028.389065
# 5459       2         -501.943700
# 5525       2         6773.958696
# 5459       1          -91.388626
# min_plan_step 3
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778   9.741205   880.680735  628.618000
# 5519       2         245.700000  26.886166  6605.931100  385.028024
# 5459       2         102.493934   9.930569  1017.823042  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -252.062735
# 5519       2        -6220.903076
# 5459       2         -430.841503
# 5525       2        -7015.934328
# 5459       1         -253.566795
# max_plan_step 3
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778   9.741205   880.680735   942.927000
# 5519       2         245.700000  26.886166  6605.931100   577.542035
# 5459       2         102.493934   9.930569  1017.823042   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          -62.246265
# 5519       2         6028.389065
# 5459       2          137.350734
# 5525       2         6783.054163
# 5459       1          -91.388626
# min_plan_step 4
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778   9.691007   876.142415  628.618000
# 5519       2         270.270000  26.322565  7114.199649  385.028024
# 5459       2         102.493934   9.968834  1021.745004  586.981538
# 5525       2         284.700000  26.432803  7525.418894  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -247.524415
# 5519       2        -6729.171625
# 5459       2         -434.763465
# 5525       2        -7059.658565
# 5459       1         -253.566795
# max_plan_step 4
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778   9.691007   876.142415   942.927000
# 5519       2         270.270000  26.322565  7114.199649   577.542035
# 5459       2         102.493934   9.968834  1021.745004   880.472308
# 5525       2         284.700000  26.432803  7525.418894   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          -66.784585
# 5519       2         6536.657614
# 5459       2          141.272696
# 5525       2         6826.778400
# 5459       1          -91.388626
# min_plan_step 5
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -253.566795
# max_plan_step 5
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -91.388626
# min_plan_step 6
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.627052  6542.266621  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         313.170000  27.185655  8513.731471  465.760329
# 5459       1         104.698925   9.011340   943.477638  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6157.238597
# 5459       2         -522.973723
# 5525       2        -8047.971142
# 5459       1         -253.566795
# max_plan_step 6
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.627052  6542.266621   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         313.170000  27.185655  8513.731471   698.640494
# 5459       1         104.698925   9.011340   943.477638  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         5964.724586
# 5459       2          229.482953
# 5525       2         7815.090977
# 5459       1          -91.388626
# min_plan_step 7
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         115.168817   8.495524   978.419455  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -288.508612
# max_plan_step 7
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         115.168817   8.495524   978.419455  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -56.446809
# min_plan_step 8
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         115.168817   8.538442   983.362322  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -293.451480
# max_plan_step 8
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         115.168817   8.538442   983.362322  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -51.503941
# min_plan_step 9
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         115.168817   8.431146   971.005153  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -281.094311
# max_plan_step 9
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         115.168817   8.431146   971.005153  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -63.861110
# min_plan_step 10
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         115.168817   8.495524   978.419455  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -288.508612
# max_plan_step 10
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         115.168817   8.495524   978.419455  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -56.446809
# min_plan_step 11
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148  628.618000
# 5519       2         245.700000  26.872258  6602.513677  385.028024
# 5459       2         112.743328   9.844975  1109.955261  586.981538
# 5525       2         284.700000  26.279223  7481.694657  465.760329
# 5459       1         115.168817   8.538442   983.362322  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -985.783148
# 5519       2        -6217.485653
# 5459       2         -522.973723
# 5525       2        -7015.934328
# 5459       1         -293.451480
# max_plan_step 11
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.407778  17.856883  1614.401148   942.927000
# 5519       2         245.700000  26.872258  6602.513677   577.542035
# 5459       2         112.743328   9.844975  1109.955261   880.472308
# 5525       2         284.700000  26.279223  7481.694657   698.640494
# 5459       1         115.168817   8.538442   983.362322  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          671.474148
# 5519       2         6024.971641
# 5459       2          229.482953
# 5525       2         6783.054163
# 5459       1          -51.503941
# min_plan_step 12
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.534303  17.554835  1589.314747  628.618000
# 5519       2         241.855926  26.783238  6477.684941  385.028024
# 5459       2         114.308241   9.856819  1126.715665  586.981538
# 5525       2         274.604522  26.279223  7216.393351  465.760329
# 5459       1         115.986097   8.695932  1008.607242  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -960.696747
# 5519       2        -6092.656918
# 5459       2         -539.734127
# 5525       2        -6750.633022
# 5459       1         -318.696399
# max_plan_step 12
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.534303  17.554835  1589.314747   942.927000
# 5519       2         241.855926  26.783238  6477.684941   577.542035
# 5459       2         114.308241   9.856819  1126.715665   880.472308
# 5525       2         274.604522  26.279223  7216.393351   698.640494
# 5459       1         115.986097   8.695932  1008.607242  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          646.387747
# 5519       2         5900.142906
# 5459       2          246.243358
# 5525       2         6517.752857
# 5459       1          -26.259022
# min_plan_step 13
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          90.559334  17.532496  1587.731166  628.618000
# 5519       2         241.095460  26.413555  6368.188235  385.028024
# 5459       2         114.617825   9.920595  1137.076989  586.981538
# 5525       2         287.829597  26.279223  7563.938026  465.760329
# 5459       1         116.147777   8.695932  1010.013208  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -959.113166
# 5519       2        -5983.160211
# 5459       2         -550.095451
# 5525       2        -7098.177697
# 5459       1         -320.102365
# max_plan_step 13
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          90.559334  17.532496  1587.731166   942.927000
# 5519       2         241.095460  26.413555  6368.188235   577.542035
# 5459       2         114.617825   9.920595  1137.076989   880.472308
# 5525       2         287.829597  26.279223  7563.938026   698.640494
# 5459       1         116.147777   8.695932  1010.013208  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          644.804166
# 5519       2         5790.646200
# 5459       2          256.604681
# 5525       2         6865.297532
# 5459       1          -24.853056
# min_plan_step 14
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.476990  17.986310  1663.319795  628.618000
# 5519       2         241.313171  26.413555  6373.938749  385.028024
# 5459       2         114.617825   9.832220  1126.947681  586.981538
# 5525       2         287.829597  26.279223  7563.938026  465.760329
# 5459       1         116.147777   8.695932  1010.013208  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1034.701795
# 5519       2        -5988.910725
# 5459       2         -539.966142
# 5525       2        -7098.177697
# 5459       1         -320.102365
# max_plan_step 14
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.476990  17.986310  1663.319795   942.927000
# 5519       2         241.313171  26.413555  6373.938749   577.542035
# 5459       2         114.617825   9.832220  1126.947681   880.472308
# 5525       2         287.829597  26.279223  7563.938026   698.640494
# 5459       1         116.147777   8.695932  1010.013208  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          720.392795
# 5519       2         5796.396713
# 5459       2          246.475373
# 5525       2         6865.297532
# 5459       1          -24.853056
# min_plan_step 15
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353805  17.845862  1648.133263  628.618000
# 5519       2         253.367215  14.704293  3725.585782  385.028024
# 5459       2         114.777539   9.844975  1129.982024  586.981538
# 5525       2         288.268783  26.279223  7575.479504  465.760329
# 5459       1         116.231188   8.695932  1010.738544  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1019.515263
# 5519       2        -3340.557759
# 5459       2         -543.000485
# 5525       2        -7109.719175
# 5459       1         -320.827702
# max_plan_step 15
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353805  17.845862  1648.133263   942.927000
# 5519       2         253.367215  14.704293  3725.585782   577.542035
# 5459       2         114.777539   9.844975  1129.982024   880.472308
# 5525       2         288.268783  26.279223  7575.479504   698.640494
# 5459       1         116.231188   8.695932  1010.738544  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          705.206263
# 5519       2         3148.043747
# 5459       2          249.509716
# 5525       2         6876.839010
# 5459       1          -24.127719
# min_plan_step 16
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.417034  17.968180  1660.565882  628.618000
# 5519       2         262.871343  26.773032  7037.862945  385.028024
# 5459       2         115.758764   9.856819  1141.013202  586.981538
# 5525       2         290.966983  26.313238  7656.283414  465.760329
# 5459       1         116.743635   8.695932  1015.194744  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1031.947882
# 5519       2        -6652.834921
# 5459       2         -554.031664
# 5525       2        -7190.523085
# 5459       1         -325.283901
# max_plan_step 16
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.417034  17.968180  1660.565882   942.927000
# 5519       2         262.871343  26.773032  7037.862945   577.542035
# 5459       2         115.758764   9.856819  1141.013202   880.472308
# 5525       2         290.966983  26.313238  7656.283414   698.640494
# 5459       1         116.743635   8.695932  1015.194744  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          717.638882
# 5519       2         6460.320910
# 5459       2          260.540894
# 5525       2         6957.642920
# 5459       1          -19.671520
# min_plan_step 17
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353805  17.572303  1622.869096  628.618000
# 5519       2         253.367215  14.704293  3725.585782  385.028024
# 5459       2         116.056112   9.856819  1143.944111  586.981538
# 5525       2         288.268783  26.279223  7575.479504  465.760329
# 5459       1         116.231188   8.695932  1010.738544  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -994.251096
# 5519       2        -3340.557759
# 5459       2         -556.962573
# 5525       2        -7109.719175
# 5459       1         -320.827702
# max_plan_step 17
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353805  17.572303  1622.869096   942.927000
# 5519       2         253.367215  14.704293  3725.585782   577.542035
# 5459       2         116.056112   9.856819  1143.944111   880.472308
# 5525       2         288.268783  26.279223  7575.479504   698.640494
# 5459       1         116.231188   8.695932  1010.738544  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          679.942096
# 5519       2         3148.043747
# 5459       2          263.471804
# 5525       2         6876.839010
# 5459       1          -24.127719
# min_plan_step 18
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.368884  18.489873  1707.888953  628.618000
# 5519       2         255.633648  27.182725  6948.819154  385.028024
# 5459       2         112.312281  10.152005  1140.194797  586.981538
# 5525       2         288.912218  26.279223  7592.388477  465.760329
# 5459       1         116.353391   8.695932  1011.801206  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1079.270953
# 5519       2        -6563.791130
# 5459       2         -553.213259
# 5525       2        -7126.628148
# 5459       1         -321.890364
# max_plan_step 18
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.368884  18.489873  1707.888953   942.927000
# 5519       2         255.633648  27.182725  6948.819154   577.542035
# 5459       2         112.312281  10.152005  1140.194797   880.472308
# 5525       2         288.912218  26.279223  7592.388477   698.640494
# 5459       1         116.353391   8.695932  1011.801206  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          764.961953
# 5519       2         6371.277118
# 5459       2          259.722489
# 5525       2         6893.747983
# 5459       1          -23.065057
# min_plan_step 19
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353805  17.845862  1648.133263  628.618000
# 5519       2         253.367215  14.704293  3725.585782  385.028024
# 5459       2         114.777539   9.844975  1129.982024  586.981538
# 5525       2         288.268783  26.279223  7575.479504  465.760329
# 5459       1         116.951707   8.695932  1017.004126  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1019.515263
# 5519       2        -3340.557759
# 5459       2         -543.000485
# 5525       2        -7109.719175
# 5459       1         -327.093283
# max_plan_step 19
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353805  17.845862  1648.133263   942.927000
# 5519       2         253.367215  14.704293  3725.585782   577.542035
# 5459       2         114.777539   9.844975  1129.982024   880.472308
# 5525       2         288.268783  26.279223  7575.479504   698.640494
# 5459       1         116.951707   8.695932  1017.004126  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          705.206263
# 5519       2         3148.043747
# 5459       2          249.509716
# 5525       2         6876.839010
# 5459       1          -17.862138
# min_plan_step 20
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.358384  17.973743  1660.025891  628.618000
# 5519       2         254.055453  27.182725  6905.919499  385.028024
# 5459       2         115.085821   9.831309  1131.444264  586.981538
# 5525       2         288.464172  26.279223  7580.614178  465.760329
# 5459       1         111.996599   8.674473   971.511482  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1031.407891
# 5519       2        -6520.891476
# 5459       2         -544.462726
# 5525       2        -7114.853849
# 5459       1         -281.600640
# max_plan_step 20
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.358384  17.973743  1660.025891   942.927000
# 5519       2         254.055453  27.182725  6905.919499   577.542035
# 5459       2         115.085821   9.831309  1131.444264   880.472308
# 5525       2         288.464172  26.279223  7580.614178   698.640494
# 5459       1         111.996599   8.674473   971.511482  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          717.098891
# 5519       2         6328.377464
# 5459       2          250.971957
# 5525       2         6881.973684
# 5459       1          -63.354781
# min_plan_step 21
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897  628.618000
# 5519       2         253.368527  14.704293  3725.605076  385.028024
# 5459       2         114.776348   9.844975  1129.970289  586.981538
# 5525       2         288.076288  26.279223  7570.420892  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1019.514897
# 5519       2        -3340.577053
# 5459       2         -542.988751
# 5525       2        -7104.660563
# 5459       1         -320.827127
# max_plan_step 21
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897   942.927000
# 5519       2         253.368527  14.704293  3725.605076   577.542035
# 5459       2         114.776348   9.844975  1129.970289   880.472308
# 5525       2         288.076288  26.279223  7570.420892   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          705.205897
# 5519       2         3148.063041
# 5459       2          249.497982
# 5525       2         6871.780398
# 5459       1          -24.128294
# min_plan_step 22
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.355885  17.857517  1649.246783  628.618000
# 5519       2         254.111068  27.026337  6867.691340  385.028024
# 5459       2         114.953652   9.844975  1131.715850  586.981538
# 5525       2         274.017093  26.164283  7169.460714  465.760329
# 5459       1         116.482747   8.695932  1012.926084  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1020.628783
# 5519       2        -6482.663317
# 5459       2         -544.734311
# 5525       2        -6703.700385
# 5459       1         -323.015241
# max_plan_step 22
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.355885  17.857517  1649.246783   942.927000
# 5519       2         254.111068  27.026337  6867.691340   577.542035
# 5459       2         114.953652   9.844975  1131.715850   880.472308
# 5525       2         274.017093  26.164283  7169.460714   698.640494
# 5459       1         116.482747   8.695932  1012.926084  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          706.319783
# 5519       2         6290.149305
# 5459       2          251.243542
# 5525       2         6470.820220
# 5459       1          -21.940180
# min_plan_step 23
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.344559  17.837325  1647.179916  628.618000
# 5519       2         253.553341  27.182725  6892.270740  385.028024
# 5459       2         114.091065   9.819465  1120.313216  586.981538
# 5525       2         287.612503  26.279223  7558.232969  465.760329
# 5459       1         115.823739   8.695932  1007.195394  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1018.561916
# 5519       2        -6507.242716
# 5459       2         -533.331678
# 5525       2        -7092.472640
# 5459       1         -317.284552
# max_plan_step 23
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.344559  17.837325  1647.179916   942.927000
# 5519       2         253.553341  27.182725  6892.270740   577.542035
# 5459       2         114.091065   9.819465  1120.313216   880.472308
# 5525       2         287.612503  26.279223  7558.232969   698.640494
# 5459       1         115.823739   8.695932  1007.195394  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          704.252916
# 5519       2         6314.728704
# 5459       2          239.840909
# 5525       2         6859.592475
# 5459       1          -27.670869
# min_plan_step 24
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.394754  17.597172  1625.886417  628.618000
# 5519       2         252.508165  26.907547  6794.375302  385.028024
# 5459       2         117.262250   9.933350  1164.806951  586.981538
# 5525       2         290.085253  26.279223  7623.214930  465.760329
# 5459       1         118.240194   8.695932  1028.208717  689.910842
#
#                             diff
# product_id store_id
# 5455       2         -997.268417
# 5519       2        -6409.347278
# 5459       2         -577.825413
# 5525       2        -7157.454601
# 5459       1         -338.297874
# max_plan_step 24
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.394754  17.597172  1625.886417   942.927000
# 5519       2         252.508165  26.907547  6794.375302   577.542035
# 5459       2         117.262250   9.933350  1164.806951   880.472308
# 5525       2         290.085253  26.279223  7623.214930   698.640494
# 5459       1         118.240194   8.695932  1028.208717  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          682.959417
# 5519       2         6216.833266
# 5459       2          284.334643
# 5525       2         6924.574436
# 5459       1           -6.657547
# min_plan_step 25
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897  628.618000
# 5519       2         253.368527  14.704293  3725.605076  385.028024
# 5459       2         114.776348   9.844975  1129.970289  586.981538
# 5525       2         288.076288  26.279223  7570.420892  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1019.514897
# 5519       2        -3340.577053
# 5459       2         -542.988751
# 5525       2        -7104.660563
# 5459       1         -320.827127
# max_plan_step 25
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897   942.927000
# 5519       2         253.368527  14.704293  3725.605076   577.542035
# 5459       2         114.776348   9.844975  1129.970289   880.472308
# 5525       2         288.076288  26.279223  7570.420892   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          705.205897
# 5519       2         3148.063041
# 5459       2          249.497982
# 5525       2         6871.780398
# 5459       1          -24.128294
# min_plan_step 26
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897  628.618000
# 5519       2         253.368527  14.704293  3725.605076  385.028024
# 5459       2         114.776348   9.844975  1129.970289  586.981538
# 5525       2         288.076288  26.279223  7570.420892  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1019.514897
# 5519       2        -3340.577053
# 5459       2         -542.988751
# 5525       2        -7104.660563
# 5459       1         -320.827127
# max_plan_step 26
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          92.353785  17.845862  1648.132897   942.927000
# 5519       2         253.368527  14.704293  3725.605076   577.542035
# 5459       2         114.776348   9.844975  1129.970289   880.472308
# 5525       2         288.076288  26.279223  7570.420892   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          705.205897
# 5519       2         3148.063041
# 5459       2          249.497982
# 5525       2         6871.780398
# 5459       1          -24.128294
# min_plan_step 27
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  18.988010  1842.946755  628.618000
# 5519       2         253.368527  14.704293  3725.605076  385.028024
# 5459       2         114.776348   9.920996  1138.695634  586.981538
# 5525       2         288.076288  26.279223  7570.420892  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1214.328755
# 5519       2        -3340.577053
# 5459       2         -551.714096
# 5525       2        -7104.660563
# 5459       1         -320.827127
# max_plan_step 27
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          97.058446  18.988010  1842.946755   942.927000
# 5519       2         253.368527  14.704293  3725.605076   577.542035
# 5459       2         114.776348   9.920996  1138.695634   880.472308
# 5525       2         288.076288  26.279223  7570.420892   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          900.019755
# 5519       2         3148.063041
# 5459       2          258.223326
# 5525       2         6871.780398
# 5459       1          -24.128294
# min_plan_step 28
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  18.988010  1842.946755  628.618000
# 5519       2         277.938527  24.779258  6887.110397  385.028024
# 5459       2         114.776348   9.920996  1138.695634  586.981538
# 5525       2         288.076288  26.463094  7623.389847  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1214.328755
# 5519       2        -6502.082373
# 5459       2         -551.714096
# 5525       2        -7157.629518
# 5459       1         -320.827127
# max_plan_step 28
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          97.058446  18.988010  1842.946755   942.927000
# 5519       2         277.938527  24.779258  6887.110397   577.542035
# 5459       2         114.776348   9.920996  1138.695634   880.472308
# 5525       2         288.076288  26.463094  7623.389847   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          900.019755
# 5519       2         6309.568362
# 5459       2          258.223326
# 5525       2         6924.749353
# 5459       1          -24.128294
# min_plan_step 29
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060  628.618000
# 5519       2         253.368527  14.704293  3725.605076  385.028024
# 5459       2         120.938628   9.856819  1192.070186  586.981538
# 5525       2         288.076288  26.279223  7570.420892  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1115.974060
# 5519       2        -3340.577053
# 5459       2         -605.088647
# 5525       2        -7104.660563
# 5459       1         -320.827127
# max_plan_step 29
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060   942.927000
# 5519       2         253.368527  14.704293  3725.605076   577.542035
# 5459       2         120.938628   9.856819  1192.070186   880.472308
# 5525       2         288.076288  26.279223  7570.420892   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          801.665060
# 5519       2         3148.063041
# 5459       2          311.597878
# 5525       2         6871.780398
# 5459       1          -24.128294
# min_plan_step 30
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060  628.618000
# 5519       2         253.368527   0.481928   122.105314  385.028024
# 5459       2         120.938628   9.856819  1192.070186  586.981538
# 5525       2         316.546288  25.235816  7988.303999  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1115.974060
# 5519       2          262.922709
# 5459       2         -605.088647
# 5525       2        -7522.543669
# 5459       1         -320.827127
# max_plan_step 30
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060   942.927000
# 5519       2         253.368527   0.481928   122.105314   577.542035
# 5459       2         120.938628   9.856819  1192.070186   880.472308
# 5525       2         316.546288  25.235816  7988.303999   698.640494
# 5459       1         116.231122   8.695932  1010.737970  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          801.665060
# 5519       2         -455.436721
# 5459       2          311.597878
# 5525       2         7289.663505
# 5459       1          -24.128294
# min_plan_step 31
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060  628.618000
# 5519       2         253.368527   0.481928   122.105314  385.028024
# 5459       2         120.938628   9.856819  1192.070186  586.981538
# 5525       2         316.546288  25.235816  7988.303999  465.760329
# 5459       1         123.286813   8.717392  1074.739416  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1115.974060
# 5519       2          262.922709
# 5459       2         -605.088647
# 5525       2        -7522.543669
# 5459       1         -384.828573
# max_plan_step 31
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060   942.927000
# 5519       2         253.368527   0.481928   122.105314   577.542035
# 5459       2         120.938628   9.856819  1192.070186   880.472308
# 5525       2         316.546288  25.235816  7988.303999   698.640494
# 5459       1         123.286813   8.717392  1074.739416  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          801.665060
# 5519       2         -455.436721
# 5459       2          311.597878
# 5525       2         7289.663505
# 5459       1           39.873152
# min_plan_step 32
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          97.058446  17.974655  1744.592060  628.618000
# 5519       2         253.368527   0.481928   122.105314  385.028024
# 5459       2         120.938628   9.856819  1192.070186  586.981538
# 5525       2         316.546288  25.235816  7988.303999  465.760329
# 5459       1         116.231122   8.695932  1010.737970  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1115.974060
# 5519       2          262.922709
# 5459       2         -605.088647
# ...
# 5455       2          96.164473  17.666131  1698.854196  628.618000
# 5519       2         196.560000  26.379162  5185.088121  385.028024
# 5459       2         120.812401   9.933350  1200.071839  586.981538
# 5525       2         227.760000  24.970601  5687.304162  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1070.236196
# 5519       2        -4800.060097
# 5459       2         -613.090301
# 5525       2        -5221.543832
# 5459       1         -320.794749
# max_plan_step 239
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196   942.927000
# 5519       2         196.560000  26.379162  5185.088121   577.542035
# 5459       2         120.812401   9.933350  1200.071839   880.472308
# 5525       2         227.760000  24.970601  5687.304162   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          755.927196
# 5519       2         4607.546085
# 5459       2          319.599531
# 5525       2         4988.663668
# 5459       1          -24.160672
# min_plan_step 240
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196  628.618000
# 5519       2         196.560000  26.379162  5185.088121  385.028024
# 5459       2         120.812401   9.933350  1200.071839  586.981538
# 5525       2         227.760000  24.970601  5687.304162  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1070.236196
# 5519       2        -4800.060097
# 5459       2         -613.090301
# 5525       2        -5221.543832
# 5459       1         -320.794749
# max_plan_step 240
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196   942.927000
# 5519       2         196.560000  26.379162  5185.088121   577.542035
# 5459       2         120.812401   9.933350  1200.071839   880.472308
# 5525       2         227.760000  24.970601  5687.304162   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          755.927196
# 5519       2         4607.546085
# 5459       2          319.599531
# 5525       2         4988.663668
# 5459       1          -24.160672
# min_plan_step 241
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196  628.618000
# 5519       2         196.560000  26.379162  5185.088121  385.028024
# 5459       2         120.812401   9.933350  1200.071839  586.981538
# 5525       2         227.760000  24.970601  5687.304162  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1070.236196
# 5519       2        -4800.060097
# 5459       2         -613.090301
# 5525       2        -5221.543832
# 5459       1         -320.794749
# max_plan_step 241
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196   942.927000
# 5519       2         196.560000  26.379162  5185.088121   577.542035
# 5459       2         120.812401   9.933350  1200.071839   880.472308
# 5525       2         227.760000  24.970601  5687.304162   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          755.927196
# 5519       2         4607.546085
# 5459       2          319.599531
# 5525       2         4988.663668
# 5459       1          -24.160672
# min_plan_step 242
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          98.011118  17.975008  1761.750626  628.618000
# 5519       2         196.560000  26.379162  5185.088121  385.028024
# 5459       2         120.812401   9.831309  1187.744043  586.981538
# 5525       2         227.760000  24.970601  5687.304162  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1133.132626
# 5519       2        -4800.060097
# 5459       2         -600.762505
# 5525       2        -5221.543832
# 5459       1         -320.794749
# max_plan_step 242
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          98.011118  17.975008  1761.750626   942.927000
# 5519       2         196.560000  26.379162  5185.088121   577.542035
# 5459       2         120.812401   9.831309  1187.744043   880.472308
# 5525       2         227.760000  24.970601  5687.304162   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          818.823626
# 5519       2         4607.546085
# 5459       2          307.271735
# 5525       2         4988.663668
# 5459       1          -24.160672
# min_plan_step 243
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196  628.618000
# 5519       2         221.130000  24.306811  5374.965185  385.028024
# 5459       2         120.812401   9.933350  1200.071839  586.981538
# 5525       2         227.760000  25.232909  5747.047384  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1070.236196
# 5519       2        -4989.937161
# 5459       2         -613.090301
# 5525       2        -5281.287055
# 5459       1         -320.794749
# max_plan_step 243
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          96.164473  17.666131  1698.854196   942.927000
# 5519       2         221.130000  24.306811  5374.965185   577.542035
# 5459       2         120.812401   9.933350  1200.071839   880.472308
# 5525       2         227.760000  25.232909  5747.047384   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          755.927196
# 5519       2         4797.423149
# 5459       2          319.599531
# 5525       2         5048.406890
# 5459       1          -24.160672
# min_plan_step 244
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          96.164473  17.618893  1694.311568  628.618000
# 5519       2         196.560000  26.379162  5185.088121  385.028024
# 5459       2         122.447641   9.682778  1185.633314  586.981538
# 5525       2         227.760000  24.970601  5687.304162  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1065.693568
# 5519       2        -4800.060097
# 5459       2         -598.651775
# 5525       2        -5221.543832
# 5459       1         -320.794749
# max_plan_step 244
#                           price    s_count       amount     max_plan  \
# product_id store_id
# 5455       2          96.164473  17.618893  1694.311568   942.927000
# 5519       2         196.560000  26.379162  5185.088121   577.542035
# 5459       2         122.447641   9.682778  1185.633314   880.472308
# 5525       2         227.760000  24.970601  5687.304162   698.640494
# 5459       1         118.969188   8.495524  1010.705592  1034.866263
#
#                             diff
# product_id store_id
# 5455       2          751.384568
# 5519       2         4607.546085
# 5459       2          305.161006
# 5525       2         4988.663668
# 5459       1          -24.160672
# min_plan_step 245
#                           price    s_count       amount    min_plan  \
# product_id store_id
# 5455       2          96.164473  17.618893  1694.311568  628.618000
# 5519       2         196.560000  27.079506  5322.747641  385.028024
# 5459       2         122.447641   9.682778  1185.633314  586.981538
# 5525       2         256.230000  25.938057  6646.108298  465.760329
# 5459       1         118.969188   8.495524  1010.705592  689.910842
#
#                             diff
# product_id store_id
# 5455       2        -1065.693568
# 5519       2        -4937.719617
# 5459       2         -598.651775
# 5525       2        -6180.347969
# 5459       1         -320.794749
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-9d71b5781678> in <module>
#      39 opt.set_maxeval(500)
#      40
# ---> 41 X = opt.optimize(pc_to_optimize['price'])
#      42 maxf = opt.last_optimum_value()
#      43
#
# ~\Anaconda3\lib\site-packages\nlopt\nlopt.py in optimize(self, *args)
#     332
#     333     def optimize(self, *args):
# --> 334         return _nlopt.opt_optimize(self, *args)
#     335
#     336     def last_optimize_result(self):
#
# <ipython-input-30-96c8849a2f9e> in vector_max_plan_constrain(result_max, X, grad)
#       7
#       8     max_plan_dt=change_context(X,max_plan_dt)
# ----> 9     max_plan_dt['amount'] = X*predict_calculation(max_plan_dt, dict_for_model)['s_count']
#      10
#      11     result_tab_sum=max_plan_dt.set_index(['product_id','store_id']).join(target_plan.set_index(['product_id','store_id']), sort=False)
#
# <ipython-input-27-1e146933240b> in predict_calculation(predict_dt, dict_for_model, model_tag)
#       9              #  print(product,store,model_name,model,dt_columns)
#      10                 product_store_dt = predict_dt[dt_columns][(predict_dt['product_id']==product) & (predict_dt['store_id']==store)]
# ---> 11                 predict_dt2 = model.predict(product_store_dt)
#      12                 predict_dt.loc[((predict_dt['product_id']==product)& (predict_dt['store_id']==store) ),'s_count'] = predict_dt2
#      13             #y_predict[product_id == product]
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py in predict(self, X, **predict_params)
#     243         check_is_fitted(self)
#     244         return self.final_estimator_.predict(
# --> 245             self.transform(X), **predict_params
#     246         )
#     247
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py in transform(self, X)
#     694             Prediction outputs for each estimator.
#     695         """
# --> 696         return self._transform(X)
#     697
#     698     def _sk_visual_block_(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py in _transform(self, X)
#     212         """Concatenate and return the predictions of the estimators."""
#     213         check_is_fitted(self)
# --> 214         predictions = [
#     215             getattr(est, meth)(X)
#     216             for est, meth in zip(self.estimators_, self.stack_method_)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_stacking.py in <listcomp>(.0)
#     213         check_is_fitted(self)
#     214         predictions = [
# --> 215             getattr(est, meth)(X)
#     216             for est, meth in zip(self.estimators_, self.stack_method_)
#     217             if est != 'drop'
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     794         # Parallel loop
#     795         lock = threading.Lock()
# --> 796         Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     797                  **_joblib_parallel_args(require="sharedmem"))(
#     798             delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1049                 self._iterating = self._original_iterator is not None
#    1050
# -> 1051             while self.dispatch_one_batch(iterator):
#    1052                 pass
#    1053
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _accumulate_prediction(predict, X, out, lock)
#     464     complains that it cannot pickle it when placed there.
#     465     """
# --> 466     prediction = predict(X, check_input=False)
#     467     with lock:
#     468         if len(out) == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     426         check_is_fitted(self)
#     427         X = self._validate_X_predict(X, check_input)
# --> 428         proba = self.tree_.predict(X)
#     429         n_samples = X.shape[0]
#     430
#
# KeyboardInterrupt:

# %%
X

# %%
pc_to_optimize_result = pd.DataFrame(np.hstack((pc_to_optimize[['s_date','product_id','store_id','price']],pd.DataFrame(X))))#.columns(['s_date','product_id','store_id','price','opt_price'])
pc_to_optimize_result.columns = ['s_date','product_id','store_id','price','opt_price']
pc_to_optimize_result
